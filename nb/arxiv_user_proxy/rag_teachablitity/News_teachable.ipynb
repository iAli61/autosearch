# %%
import asyncio
from typing import Dict, List, Optional, Union, Callable
from autogen.agentchat.contrib.retrieve_user_proxy_agent import RetrieveUserProxyAgent
from autogen.agentchat.contrib.web_surfer import WebSurferAgent 
from autogen.agentchat.contrib.agent_builder import AgentBuilder
from autogen.formatting_utils import colored
from typing_extensions import Annotated
import autogen

from teachability import Teachability
from concurrent.futures import ThreadPoolExecutor, as_completed

import arxiv

import requests
from unstructured.chunking.title import chunk_by_title
from unstructured.partition.pdf import partition_pdf

import os
import shutil
import requests
import pickle
import re
from pathlib import Path

import nest_asyncio
nest_asyncio.apply()

version = "0.0.1"
ProjectID = "FinNews"
initiate_db = True
config_file = "OAI_CONFIG_LIST-sweden-505"
agents_json = "./news-0.0.1.json"


Project_dir = Path(f"./{ProjectID}/{version}")

if not os.path.exists(Project_dir): initiate_db = True

output_dir = f'{Project_dir}/pdf_output'
if not os.path.exists(output_dir): os.makedirs(output_dir)

db_dir = f'{Project_dir}/memo-db/'
# check if db_dir exists, delete it if it does
if initiate_db:

    if not os.path.exists(Project_dir): 
        shutil.rmtree(Project_dir)
        os.makedirs(Project_dir)
    if os.path.exists(db_dir): shutil.rmtree(db_dir)

    # create a list of papers that have been read and saved it in a pickle file
    read_papers = []
    with open(f'{Project_dir}/read_papers.pkl', 'wb') as f:
        pickle.dump(read_papers, f)

    # create a list of abstract that have been read and saved it in a pickle file
    read_abstracts = []
    with open(f'{Project_dir}/read_abstracts.pkl', 'wb') as f:
        pickle.dump(read_abstracts, f)

config_list = autogen.config_list_from_json(
    config_file,
    file_location=".",
    filter_dict={
        "model": ["gpt-4-32k", "gpt-4", "gpt4", "gpt-35-turbo-16k", "gpt-4-0613", "gpt-3.5-turbo", "gpt-35-turbo", "gpt-35-turbo-0613"]
    },
)

print("LLM models: ", [config_list[i]["model"] for i in range(len(config_list))])

# Configuration for the Language Model (LLM)
llm_config = {
    "config_list": config_list,  # config_list should be defined or imported
    "timeout": 120,
    # "seed": 42,
}

# Configuration for the manager using the same config_list as llm_config
manager_config = {
    "config_list": config_list,  # config_list should be defined or imported
    "timeout": 60,
    # "seed": 42,
}

# Termination message definition
termination_msg = (
    lambda x: isinstance(x, dict)
    and str(x.get("content", "")).upper() == "TERMINATE"
)

######################
bing_api_key = "bc0eaf95b2034706812cbc2ba03c1a99"

summarizer_llm_config = {
    "timeout": 600,
    "cache_seed": 44,  # change the seed for different trials
    "config_list": autogen.config_list_from_json(
        config_file,
        filter_dict={"model": ["gpt-4-32k", "gpt-35-turbo-16k"]},
    ),
    "temperature": 0,
}

print("Summarizer LLM models: ", [summarizer_llm_config["config_list"][i]["model"] for i in range(len(summarizer_llm_config["config_list"]))])
# Out:
# LLM models:  ['gpt-4', 'gpt-4-32k', 'gpt-35-turbo', 'gpt-35-turbo-16k']
# Summarizer LLM models:  ['gpt-4-32k', 'gpt-35-turbo-16k']

# %%
new_builder = AgentBuilder(config_file_or_env=config_file)
agent_list, agent_configs = new_builder.load(agents_json)

agents_dict = {}
for agent in agent_list:
    agents_dict[agent.name] = agent

# create websurfer agent
web_surfer = WebSurferAgent(
    "web_surfer",
    llm_config=llm_config,
    summarizer_llm_config=summarizer_llm_config,
    browser_config={"viewport_size": 4096, "bing_api_key": bing_api_key},
)

agents_dict["web_surfer"] = web_surfer
# Out:
# Loading config from ./news-0.0.1.json
# ==> Creating agents...
# Creating agent financial_news_research_analyst with backbone gpt-4...
# Creating agent central_banks_insights_specialist with backbone gpt-4...
# Creating agent global_monetary_policy_analyst with backbone gpt-4...
# Creating agent financial_data_analyst with backbone gpt-4...
# Creating agent python_financial_news_aggregator_developer with backbone gpt-4...
# Adding user console proxy...

# %%
def start_task(execution_task: str, agents: Dict[str, Union[str, List[str]]]):
    group_chat = autogen.GroupChat(agents=list(agents.values()), messages=[], max_round=12)
    manager = autogen.GroupChatManager(groupchat=group_chat, llm_config={"config_list": config_list, **llm_config})
    agent_list[0].initiate_chat(manager, message=execution_task)

# %%
# By employing the 'get_news' function with precise queries, you can access the most up-to-date news.

task = """
As a seasoned financial analysis writer, your expertise is called upon to compose an insightful weekly blog post that delves into the pivotal financial happenings from the preceding week. 
By web surfing, you MUST get the most up-to-date news. 
Your readers rely on your analytical prowess to unpack complex financial events and trends. 
Address the following crucial inquiries in your upcoming blog post to provide them with the clarity they seek:

Insights from recent central bank officials' statements, particularly from the Federal Reserve (Fed) and the European Central Bank (ECB).
Emerging trends in global monetary policy.
Key outcomes and implications from the latest Federal Reserve meeting.
Notable monetary policy meetings that occurred last week, with a focus on actions by the ECB, Fed, Bank of England (BoE), and Bank of Japan (BoJ).
A review of the latest inflation data from the Euro Area, the United Kingdom, Japan, and the United States.
Analysis of recent labor market reports from the USA and the Euro Area, including an examination of wage negotiations in Germany, France, Spain, and Italy.
Factors influencing the EUR/USD exchange rate fluctuations over the past week, including inflation data, fiscal budgets, and trade-related tariffs.
Developments in the pricing of inflation swaps in both the Eurozone and the United States.
Your discerning analysis is not just expected, but essential for readers who depend on your weekly posts to make informed financial decisions.
"""

start_task(task, agents_dict)
# Out:
# User_console_and_code_interpreter (to chat_manager):
#
#
# As a seasoned financial analysis writer, your expertise is called upon to compose an insightful weekly blog post that delves into the pivotal financial happenings from the preceding week.
# By web surfing, you MUST get the most up-to-date news.
# Your readers rely on your analytical prowess to unpack complex financial events and trends.
# Address the following crucial inquiries in your upcoming blog post to provide them with the clarity they seek:
#
# Insights from recent central bank officials' statements, particularly from the Federal Reserve (Fed) and the European Central Bank (ECB).
# Emerging trends in global monetary policy.
# Key outcomes and implications from the latest Federal Reserve meeting.
# Notable monetary policy meetings that occurred last week, with a focus on actions by the ECB, Fed, Bank of England (BoE), and Bank of Japan (BoJ).
# A review of the latest inflation data from the Euro Area, the United Kingdom, Japan, and the United States.
# Analysis of recent labor market reports from the USA and the Euro Area, including an examination of wage negotiations in Germany, France, Spain, and Italy.
# Factors influencing the EUR/USD exchange rate fluctuations over the past week, including inflation data, fiscal budgets, and trade-related tariffs.
# Developments in the pricing of inflation swaps in both the Eurozone and the United States.
# Your discerning analysis is not just expected, but essential for readers who depend on your weekly posts to make informed financial decisions.
#
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> USING AUTO REPLY...
#
# >>>>>>>> EXECUTING FUNCTION informational_web_search...
#
# >>>>>>>> EXECUTING FUNCTION informational_web_search...
#
# >>>>>>>> EXECUTING FUNCTION informational_web_search...
#
# >>>>>>>> EXECUTING FUNCTION informational_web_search...
#
# >>>>>>>> EXECUTING FUNCTION informational_web_search...
#
# >>>>>>>> EXECUTING FUNCTION informational_web_search...
#
# >>>>>>>> EXECUTING FUNCTION informational_web_search...
#
# >>>>>>>> EXECUTING FUNCTION informational_web_search...
#
# >>>>>>>> EXECUTING FUNCTION informational_web_search...
#
# >>>>>>>> EXECUTING FUNCTION informational_web_search...
# web_surfer (to chat_manager):
#
# Address: bing: recent statements by central bank officials Federal Reserve
# Title: recent statements by central bank officials Federal Reserve - Search
# Viewport position: Showing page 1 of 1.
# =======================
# A Bing search for 'recent statements by central bank officials Federal Reserve' found 11 results:
#
# ## Web Results
# 1. [Fed's Powell says restrictive rates policy needs more time to work](https://www.reuters.com/markets/us/feds-powell-jefferson-square-restrictive-policy-with-strong-data-2024-04-16/)
# WASHINGTON, April 16 (Reuters) - Top U.S. central bank officials including Federal Reserve Chair Jerome Powell backed away on Tuesday from providing any guidance on when interest rates may be cut ...
#
# 2. [Federal Reserve Board - Fed Financial Statements](https://www.federalreserve.gov/aboutthefed/fed-financial-statements.htm)
# The Board of Governors and the Federal Reserve Banks annually prepare and release audited financial statements reflecting balances (as of December 31) and income and expenses for the year then ended. The Federal Reserve Bank financial statements also include the accounts and results of operations of two limited liability companies (LLCs) that ...
#
# 3. [Fed Chair Powell says there has been a 'lack of further progress' this ...](https://www.nbcnews.com/business/economy/fed-chair-powell-says-lack-progress-year-inflation-rcna148075)
# Federal Reserve Bank Chair Jerome Powell at a forum at Stanford University in Stanford, Calif., on April 3. ... Echoing recent statements by central bank officials, Powell indicated the current ...
#
# 4. [Key takeaways from the Fed’s rate decision and Powell’s press ...](https://www.cnn.com/2024/03/20/economy/what-to-expect-from-the-fed-meeting/index.html)
# The Federal Reserve held its key interest rate steady Wednesday for the fifth consecutive meeting, as the central bank awaits more data to determine when to cut rates. CNN values your feedback 1.
#
# 5. [Federal Reserve issues FOMC statement](https://www.federalreserve.gov/newsevents/pressreleases/monetary20210922a.htm)
# Federal Reserve issues FOMC statement. For release at 2:00 p.m. EDT. The Federal Reserve is committed to using its full range of tools to support the U.S. economy in this challenging time, thereby promoting its maximum employment and price stability goals. With progress on vaccinations and strong policy support, indicators of economic activity ...
#
# 6. [Federal Reserve Board - Federal Reserve issues FOMC statement](https://www.federalreserve.gov/newsevents/pressreleases/monetary20220316a.htm)
# Job gains have been strong in recent months, and the unemployment rate has decline ... The Federal Reserve, the central bank of the United States, provides the nation with a safe, flexible, and stable monetary and financial system. Main Menu Toggle ... Federal Reserve issues FOMC statement. For release at 2:00 p.m. EDT
#
# 7. [Jay Powell reveals Federal Reserve’s hand on US interest rates](https://www.ft.com/content/b8c0a36d-bcb7-4087-b474-8659f6e46bd5)
# Jun 2023. Mar 2023. Source: Federal Reserve. FT graphic: Eva Xiao. They now anticipate the policy rate falling by 0.75 percentage points in 2024 and another full percentage point in 2025, before ...
#
# 8. [Federal Reserve News - The New York Times](https://www.nytimes.com/live/2022/06/15/business/fed-reserve-meeting)
# Federal Reserve News. Fed Takes Aggressive Action in Inflation Fight. Policymakers announced a large interest rate increase to rein in prices while trying to keep the economy from falling into a ...
#
# 9. [Powell Suggests Interest Rates Could Stay High for ... - The New York Times](https://www.nytimes.com/2024/04/16/business/powell-interest-rates-inflation.html)
# The Federal Reserve is likely to wait longer than initially expected to cut interest rates, given stubborn inflation readings in recent months, the central bank’s top two officials said Tuesday ...
#
# 10. [Federal Reserve triggers market rally as it signals interest rate cuts ...](https://www.ft.com/content/ff1f4787-57fb-4187-a215-5a32c55deeed)
# Federal Reserve. Jay Powell reveals Federal Reserve’s hand on US interest rates. European stocks and government bonds joined the rally on Thursday morning. The region-wide Stoxx Europe 600 rose ...
#
# ## News Results:
# 11. [European Central Bank Announces Independence from Federal Reserve Policies](https://www.msn.com/en-us/money/markets/european-central-bank-announces-independence-from-federal-reserve-policies/ar-BB1lB6fK)
# The European Central Bank (ECB) has made a bold declaration of its independence from the Federal Reserve's policy directions.
#
# Address: bing: recent statements by central bank officials European Central Bank
# Title: recent statements by central bank officials European Central Bank - Search
# Viewport position: Showing page 1 of 1.
# =======================
# A Bing search for 'recent statements by central bank officials European Central Bank' found 14 results:
#
# ## Web Results
# 1. [Press releases - European Central Bank](https://www.ecb.europa.eu/press/pr/html/index.en.html)
# Asset purchase programmes. Latest monetary policy press conference. 7 March 2024. Introduction. Benefits of price stability. Scope of monetary policy. Transmission mechanism. Decisions, statements & accounts. Monetary policy strategy.
#
# 2. [By Date](https://www.ecb.europa.eu/press/pubbydate/html/index.en.html)
# Monetary policy statements; Monetary policy statements at a glance; Conferences & seminars. Forum on Central Banking. Young Economist Prize; Past editions; Civil society engagement; Calendars. Weekly schedule; Meetings of the Governing Council and the General Council; Statistical calendars. Money, banking and financial markets
#
# 3. [By Activities](https://www.ecb.europa.eu/press/pr/activities/html/index.en.html)
# The European Central Bank (ECB) is the central bank of the European Union countries which have adopted the euro. Our main task is to maintain price stability in the euro area and so preserve the purchasing power of the single currency. EN. Български Čeština Dansk Deutsch Eλληνικά English Español Eesti keel Suomi Français Gaeilge Hrvatski Magyar Italiano Lietuvių Latviešu ...
#
# 4. [European Central Bank](https://www.ecb.europa.eu/)
# The European Central Bank (ECB) is the central bank of the European Union countries which have adopted the euro. ... Chief Economist Philip R. Lane reviews the recent evolution of inflation in the euro area and discusses the implications for monetary policy. ... Our monetary policy statement at a glance. QUIZ. 19 February 2024. Try our quizzes ...
#
# 5. [Statement by the Eurogroup on the decision of the ECB’s Governing ...](https://www.consilium.europa.eu/en/press/press-releases/2023/10/18/statement-by-the-eurogroup-on-the-decision-of-the-ecb-s-governing-council-to-launch-the-next-phase-of-the-digital-euro-project/)
# The Eurogroup issued a statement on the decision of the European Central Bank’s Governing Council to launch the next phase of the digital euro project. ... Latest news. Press releases ... We issued a statement in January 2023 summarising the key political dimensions of a digital euro arising from our discussions, thereby supporting the work ...
#
# 6. [European Central Bank holds interest rates at 4% in contested decision](https://www.ft.com/content/52e61581-6f66-4809-957a-2279ab173def?shareType=nongift)
# The European Central Bank sent a strong signal that it would consider cutting interest rates at its next meeting in June after holding them at all-time highs on Thursday. The ECB said after its ...
#
# 7. [Texts adopted - European Central Bank – annual report 2021 - Wednesday ...](https://www.europarl.europa.eu/doceo/document/TA-9-2022-0029_EN.html)
# B. whereas, according to the ECB staff macroeconomic projections of September 2021, global real GDP (excluding the euro area) is projected to increase by 6,3 % in 2021, before decelerating to 4,5 % in 2022 and 3,7 % in 2023; whereas global activity had already exceeded its pre-pandemic level in late 2020; C. whereas, according to Eurostat, the ...
#
# 8. [European Central Bank News - The New York Times](https://www.nytimes.com/live/2022/07/21/business/ecb-meeting-inflation-interest-rates)
# Europe joins fight against inflation, raising rates for first time in 11 years. E.C.B.’s deposit facility rate since 1999. Source: European Central Bank. FRANKFURT — As consumer prices across ...
#
# 9. [European Central Bank Signals Coming Rate Cut, Setting Up Split With ...](https://www.nytimes.com/2024/04/11/business/european-central-bank-rates.html)
# The central bank has also been watching wages, considered a sticky source of services inflation. Officials expect to get more data on annual wage negotiations by the June policy meeting.
#
# 10. [ECB Signals It’s Moving Closer to a Cut but Keeps Rates Steady](https://www.wsj.com/economy/central-banking/ecb-rate-decision-april-2024-3feb0947)
# FRANKFURT—The European Central Bank gave the clearest indication yet that it could cut interest rates in June, opening a new phase for financial markets and signaling a possible divergence with ...
#
# 11. [REPORT on the European Central Bank – annual report 2023](https://www.europarl.europa.eu/doceo/document/A-9-2023-0412_EN.html)
# MOTION FOR A EUROPEAN PARLIAMENT RESOLUTION. on European Central Bank – annual report 2023. ( 2023/2064 (INI)) The European Parliament, – having regard to the European Central Bank (ECB) annual report 2022, – having regard to the ECB’s feedback of 25 May 2023 on the input provided by Parliament as part of its resolution on the ECB’s ...
#
# 12. [REPORT on the European Central Bank Annual Report 2020](https://www.europarl.europa.eu/doceo/document/A-9-2021-0002_EN.html)
# A. whereas the Commission’s Summer 2020 Economic Forecast, taking into account economic shocks caused by the COVID-19 pandemic, projects that the euro area economy will contract by 8.7 % in 2020 and grow by 6.1 % in 2021, and the EU-27 economy will contract by 8.3 % in 2020 and grow by 5.8 % in 2021; B. whereas, according to the ECB staff ...
#
# ## News Results:
# 13. [European Central Bank Announces Independence from Federal Reserve Policies](https://www.msn.com/en-us/money/markets/european-central-bank-announces-independence-from-federal-reserve-policies/ar-BB1lB6fK)
# The European Central Bank (ECB) has made a bold declaration of its independence from the Federal Reserve's policy directions.
#
# 14. [European Central Bank to Hold Steady, but Euro Could Be Affected by Faster Rate Cuts Compared to the Fed](https://www.msn.com/en-us/money/markets/european-central-bank-to-hold-steady-but-euro-could-be-affected-by-faster-rate-cuts-compared-to-the-fed/ar-BB1lrIRY)
# Despite the headline eurozone inflation decreasing from its peak of 10.6% in October 2022 to 2.4% in March 2024, it still remains above the ECB’s 2% target. Consequently, the central bank remains cautious about reducing its deposit rate from the current 4% without further evidence indicating a reduction in price pressures.
#
# Address: bing: emerging trends in global monetary policy 2024
# Title: emerging trends in global monetary policy 2024 - Search
# Viewport position: Showing page 1 of 1.
# =======================
# A Bing search for 'emerging trends in global monetary policy 2024' found 10 results:
#
# ## Web Results
# 1. [World Economic Outlook, April 2024: Coming Soon - IMF](https://www.imf.org/en/Publications/WEO/Issues/2024/04/16/world-economic-outlook-april-2024)
# Trade, notably through global value chains, is a key propagation channel. Spillovers generate a reallocation of economic activity across firms and sectors in other countries. Looking ahead, a plausible growth acceleration in G20 emerging markets, even excluding China, could support global growth over the medium term and spill over to other ...
#
# 2. [World Economic Outlook Update, January 2024: Moderating Inflation and ...](https://www.imf.org/en/Publications/WEO/Issues/2024/01/30/world-economic-outlook-update-january-2024)
# Global growth is projected to stay at 3.1 percent in 2024 and rise to 3.2 percent in 2025. Elevated central bank rates to fight inflation and a withdrawal of fiscal support amid high debt weigh on economic activity. Inflation is falling faster than expected in most regions, amid unwinding supply-side issues and restrictive monetary policy. Global headline inflation is expected to fall to 5.8 ...
#
# 3. [JAN WORLD ECONOMIC OUTLOOK - IMF](https://www.imf.org/external/Pubs/FT/weo/2024/01/pdf/January%202024%20WEO%20Update_EN.pdf)
# the midst of unwinding supply-side issues and restrictive monetary policy. Global headline inflation is expected to fall to 5.8 percent in 2024 and to 4.4 percent in 2025, with the 2025 forecast revised down. • With disinflation and steady growth, the likelihood of a hard landing has receded, and risks to global growth are broadly balanced.
#
# 4. [IMF / April 2024 Global Financial Stability Report](https://mediacenter.imf.org/news/imf---april-2024-global-financial-stability-report/s/82e96594-9580-4e95-ae7b-2610d8b6c3fb)
# Release Date: 16 Apr 2024 | Washington, DC. In a press briefing in Washington, DC, the Director of the IMF’s Monetary and Capital Markets Department Tobias Adrian said that a sense of optimism has pervaded financial markets in recent months, amid investor confidence that the fight against inflation is entering its “last mile” and that ...
#
# 5. [Global outlook 2024: Tight monetary policy and geopolitical uncertainty ...](https://www.un.org/development/desa/dpad/wp-content/uploads/sites/45/MB178.pdf)
# Growth is forecast to improve moderately to 2.7 per cent in 2025 but will remain below the average pre-pandemic (2011–19) growth rate of 3.0 per cent. While the world economy avoided a sharp ...
#
# 6. [Global economic outlook: finding balance in 2024](https://assets.ey.com/content/dam/ey-sites/ey-com/en_us/topics/strategy-transactions/eyp_global_economic_outlook_jan_2024.pdf)
# Global Emerging markets2 2022 2025F 3.3 2023E 2024F ... While the Bank of Canada will be easing monetary policy in H2 2024 on account of lower inflation and recessionary conditions, we don’t anticipate any broad-based fiscal stimulus measures in an election year. We see GDP growth around 0.4% in 2024, after a likely 1.0% expansion in 2023.
#
# 7. [Global Monthly March 2024](https://thedocs.worldbank.org/en/doc/abf6fab46b08d9edfcf1187e6a3e108e-0350012023/related/Global-Monthly-Mar24.pdf)
# The Global Monthly is a publication of the Prospects Group. This edition was prepared by Marie Albert and Garima Vasishtha under the supervision of Carlos Arteta. The special focus was prepared by Francisco Arroyo Marioli. This Global Monthly reflects data available up to March 25th, 2024.
#
# 8. [World Economic Situation and Prospects: February 2024 Briefing, No. 178](https://www.un.org/development/desa/dpad/publication/world-economic-situation-and-prospects-february-2024-briefing-no-178/)
# Economic growth in Africa is projected to remain modest, edging up from an estimated 3.3 per cent in 2023 to 3.5 per cent in 2024 as the region is buffeted by the global economic slowdown and ...
#
# 9. [Global economic outlook 2024 | Deloitte Insights](https://www2.deloitte.com/xe/en/insights/economy/global-economic-outlook-2024.html)
# Real GDP growth is expected to be around 1% in 2024, and to average only 1.4% per year from 2024 through 2026. 45 This does not compare well with the International Monetary Fund’s 4% projection for emerging and developing economies, and even falls below the outlook for advanced economies of 1.7%. 46.
#
# 10. [IMF Lifts Growth Forecast for Global Economy, Warns of Risks](https://www.bloomberg.com/news/articles/2024-04-16/imf-lifts-growth-forecast-for-global-economy-but-warns-of-risks)
# India’s forecast was lifted to 6.8% for this year, from 6.5%. In an unusually strong criticism of the US, the IMF said that while the nation’s recent economic performance is “impressive ...
#
# Address: bing: latest Federal Reserve meeting outcomes
# Title: latest Federal Reserve meeting outcomes - Search
# Viewport position: Showing page 1 of 1.
# =======================
# A Bing search for 'latest Federal Reserve meeting outcomes' found 10 results:
#
# ## Web Results
# 1. [Fed meeting today: Live updates on March Fed rate decision - CNBC](https://www.cnbc.com/2024/03/20/fed-meeting-today-live-updates-on-march-fed-rate-decision.html)
# The Federal Reserve held steady on interest rates at the conclusion of its March meeting, and it’s sticking with its forecast for three interest rate cuts. During a news conference Fed Chair ...
#
# 2. [The Fed - Meeting calendars and information - Federal Reserve Board](https://www.federalreserve.gov/monetarypolicy/fomccalendars.htm)
# 2019 FOMC Meetings. * Meeting associated with a Summary of Economic Projections. Note: A two-day meeting is scheduled for January 28-29, 2025. Each meeting date is tentative until confirmed at the meeting immediately preceding it. Last Update: April 10, 2024. The Federal Reserve Board of Governors in Washington DC.
#
# 3. [The Fed - Monetary Policy: - Federal Reserve Board](https://www.federalreserve.gov/monetarypolicy/fomcminutes20210922.htm)
# September 21–22, 2021. A joint meeting of the Federal Open Market Committee and the Board of Governors of the Federal Reserve System was held by videoconference on Tuesday, September 21, 2021, at 1:00 p.m. and continued on Wednesday, September 22, 2021, at 9:00 a.m. 1. PRESENT: Jerome H. Powell, Chair. John C. Williams, Vice Chair.
#
# 4. [Federal Open Market Committee - Federal Reserve Board](https://www.federalreserve.gov/monetarypolicy/fomcprojtabl20231213.htm)
# Summary of Economic Projections. In conjunction with the Federal Open Market Committee (FOMC) meeting held on December 12–13, 2023, meeting participants submitted their projections of the most likely outcomes for real gross domestic product (GDP) growth, the unemployment rate, and inflation for each year from 2023 to 2026 and over the longer run.
#
# 5. [Fed Meeting Live Updates: Interest Rates Raised 0.75 Percentage Point](https://www.wsj.com/livecoverage/federal-reserve-meeting-interest-rates-june-2022)
# Officials agreed to a 0.75-percentage-point rate rise at their two-day policy meeting that concluded Wednesday, which will increase the Fed’s benchmark federal-funds rate to a range between 1.5% ...
#
# 6. [Fed Rate Decision Today: Live Updates on Policy Meeting, Powell’s ...](https://www.bloomberg.com/news/live-blog/2023-05-03/fomc-rate-decision-and-fed-chair-news-conference)
# Here are five key takeaways from Wednesday’s Federal Open Market Committee rate decision and Federal Reserve Chair Jerome Powell’s press conference: The Fed raised rates by a quarter ...
#
# 7. [Federal Reserve Meeting: Fed Leaves Rates Unchanged, for Now - The New ...](https://www.nytimes.com/live/2023/06/14/business/fed-interest-rates)
# Fed officials expect the unemployment rate to rise to 4.1 percent by the end of the year, up from 3.7 percent in May but less than the 4.5 percent in their March forecast. The strength of the ...
#
# 8. [Federal Reserve Meeting Fed Keeps Rates Steady - The New York Times](https://www.nytimes.com/live/2024/01/31/business/fed-meeting-interest-rates)
# Federal Reserve Meeting Fed Keeps Rates Steady. ... The average rate on new car loans was 7.1 percent in December 2023, according to Edmunds, up from 6.7 percent in December 2022. Used car rates ...
#
# 9. [What Happened Today at the Fed Meeting - The New York Times](https://www.nytimes.com/live/2023/05/03/business/fed-interest-rates/what-to-know-about-the-feds-latest-move)
# Federal Reserve News. What Happened Today at the Fed Meeting. The Federal Reserve raised interest rates by a quarter of a point, its 10th straight increase, as inflation remains stubbornly high ...
#
# 10. [Fed Keeps Rates Unchanged - The Wall Street Journal](https://www.wsj.com/livecoverage/fed-meeting-interest-rate-decision-fomc-november-2023/card/fed-november-meeting-data-GzFEhnyliNrwq6L1u5SZ)
# The Federal Reserve kept interest rates unchanged on Wednesday. The decision marked the second-consecutive meeting at which the Fed left rates unchanged after a [long campaign of increases](https ...
#
# Address: bing: monetary policy meetings last week ECB Fed BoE BoJ
# Title: monetary policy meetings last week ECB Fed BoE BoJ - Search
# Viewport position: Showing page 1 of 1.
# =======================
# A Bing search for 'monetary policy meetings last week ECB Fed BoE BoJ' found 11 results:
#
# ## Web Results
# 1. [Busy week for central banks as Fed, BoE and BoJ set interest rates](https://www.ft.com/content/8a7d5b2a-8118-451b-9280-1c30ae9209d3)
# The BoE will be heavily influenced by the UK inflation figures out the day before the Monetary Policy Committee meets and expected to show a slight increase in the headline rate compared with last ...
#
# 2. [The Week Ahead: Fed, ECB and BoJ set rates, and Big Tech earnings in ...](https://www.ft.com/content/dd5f810c-c0c6-41d7-add7-2fec401fa958)
# The Federal Open Market Committee begins its latest interest rate-setting meeting on Tuesday with an announcement due in the afternoon of Wednesday, and the European Central Bank follows a day ...
#
# 3. [Monetary Policy Meetings : 日本銀行 Bank of Japan](https://www.boj.or.jp/en/mopo/mpmsche_minu/index.htm)
# Statements on Monetary Policy List by Year. Summary of Opinions at the Monetary Policy Meetings List by Year. Minutes of the Monetary Policy Meetings List by Year. 2024. 2023. Past Monetary Policy Meetings. A list of scheduled dates of the meetings; policy statements; minutes of the meetings; and the Outlook for Economic Activity and Prices ...
#
# 4. [Fed, ECB, BoJ, PBOC: Central banks monetary policy decision are ... - CNBC](https://www.cnbc.com/2023/06/19/fed-ecb-boj-pboc-central-banks-monetary-policy-decision-are-diverging.html)
# The euro rose to a 15-year high against the Japanese yen on Friday, according to Reuters, off the back of the divergent monetary policy decisions. The euro also broke above the $1.09 threshold as ...
#
# 5. [The Week Ahead: Fed, ECB and BoJ set rates, and Big Tech earnings in ...](https://www.ft.com/content/dd5f810c-c0c6-41d7-add7-2fec401fa958)
# The Federal Open Market Committee begins its latest interest rate-setting meeting on Tuesday with an announcement due in the afternoon of Wednesday, and the European Central Bank follows a day ...
#
# 6. [Fed, BOJ to Lead a Week of Rate Decisions for Half the World](https://www.bloomberg.com/news/articles/2024-03-16/world-economy-latest-fed-and-boj-dominate-crucial-week-for-central-banks)
# March 17, 2024 at 11:12 AM PDT. Investors may glean more on the Federal Reserve ’s resolve to ease and how close Japan is to finally exiting negative interest rates as central banks set policy ...
#
# 7. [Webcasts: ECB monetary policy decisions - European Central Bank](https://www.ecb.europa.eu/press/press_conference/html/index.en.html)
# Webcasts of ECB press conferences. EN. ... The President will provide an in-depth explanation of the reasons behind the latest monetary policy decisions. Read from 15:00 CET. Watch the press conference. ... Find the dates for upcoming Governing Council meetings and press conferences. Governing Council meeting calendar.
#
# 8. [Bank of Japan expected to stick with negative interest rates](https://www.ft.com/content/550d3400-9ba6-477a-99ba-77db3a83e196)
# “From here, I think the BoJ — in the same way as the Fed and the ECB — will proceed with a high degree of transparency so that markets can sufficiently price in the direction of its monetary ...
#
# 9. [Bank of England set to hold interest rates as it awaits more signs on ...](https://www.ft.com/content/202fbe49-f352-4af2-bd6a-5fc36263b203)
# Financial markets are overwhelmingly betting that the BoE’s benchmark rate will be kept at 5.25 per cent when the Monetary Policy Committee announces its latest decision on Thursday.
#
# 10. [A 'momentous week' ahead as the Fed, ECB and Bank of Japan near ... - CNBC](https://www.cnbc.com/2023/07/24/a-momentous-week-ahead-as-the-fed-the-ecb-and-the-bank-of-japan-reach-a-pivotal-point.html)
# The U.S. Federal Reserve, Bank of Japan and European Central Bank will all announce key interest rate decisions this week, with each potentially nearing a pivotal moment in their monetary policy ...
#
# 11. [BoE hikes, Fed pivots, ECB rolls slow as pandemic exits diverge](https://www.reuters.com/markets/europe/boe-hikes-fed-pivots-ecb-rolls-slow-pandemic-exits-diverge-2021-12-16/)
# Summary. BoE surprises with rate hike to 0.25%. ECB cuts stimulus but maintains support. BOJ set for policy decision on Friday. Dec 16 (Reuters) - Britain became the first G7 economy to hike ...
#
# Address: bing: latest inflation data Euro Area UK Japan USA April 2024
# Title: latest inflation data Euro Area UK Japan USA April 2024 - Search
# Viewport position: Showing page 1 of 1.
# =======================
# A Bing search for 'latest inflation data Euro Area UK Japan USA April 2024' found 12 results:
#
# ## Web Results
# 1. [Annual inflation down to 2.4% in the euro area - Eurostat](https://ec.europa.eu/eurostat/web/products-euro-indicators/w/2-17042024-ap)
# The euro area flash estimate for March 2024, published on 3 April 2024, was 2.4%. The next flash estimate of euro area inflation with data for April 2024 is scheduled for 30 April 2024. Methods and definitions Annual inflation is the change of the price level of consumer goods and services between the current month and the same month of the previous year.
#
# 2. [Euro area annual inflation down to 2.4% - Eurostat](https://ec.europa.eu/eurostat/en/web/products-euro-indicators/w/2-03042024-ap)
# Overview Euro area annual inflation is expected to be 2.4% in March 2024, down from 2.6% in February according to a flash estimate from Eurostat, the statistical office of the European Union. Looking at the main components of euro area inflation, services is expected to have the highest annual rate in March (4.0%, stable compared with February), followed by food, alcohol & tobacco (2.7% ...
#
# 3. [Euro zone inflation unexpectedly eases, boosting rate cut case](https://www.reuters.com/markets/europe/euro-zone-inflation-unexpectedly-eases-boosting-rate-cut-case-2024-04-03/)
# Underlying inflation, closely watched by the ECB to gauge the durability of price pressures, meanwhile fell to 2.9% from 3.1%, coming below expectations for 3.0%, data from Eurostat, the EU's ...
#
# 4. [Economic Bulletin Issue 2, 2024 - European Central Bank](https://www.ecb.europa.eu/press/economic-bulletin/html/eb202402.en.html)
# Measures of longer-term inflation expectations remained broadly stable in February, with most standing at around 2%. The March 2024 ECB staff macroeconomic projections for the euro area foresee that headline inflation will decline gradually, averaging 2.3% in 2024, 2.0% in 2025 and 1.9% in 2026.
#
# 5. [Euro Area Inflation Rate - TRADING ECONOMICS](https://tradingeconomics.com/euro-area/inflation-cpi)
# Inflation Rate in Euro Area averaged 2.22 percent from 1991 until 2024, reaching an all time high of 10.60 percent in October of 2022 and a record low of -0.60 percent in July of 2009. This page provides the latest reported value for - Euro Area Inflation Rate - plus previous releases, historical high and low, short-term forecast and long-term prediction, economic calendar, survey consensus ...
#
# 6. [Inflation in the euro area and the US - causes, persistence, outlook](https://www.ecb.europa.eu/press/key/date/2023/html/ecb.sp230420~661bd5928c.en.pdf)
# This factor inflated the September 2022 OFI deposits, being reversed in October and November 2022. “M1 deposits” are overnight deposits. “Other deposits” includes deposits other than time and M1 deposits. Bank bonds are those held by euro area residents excluding MFIs and central government.
#
# 7. [Eurozone inflation falls more than expected: A green light ... - Euronews](https://www.euronews.com/business/2024/04/03/eurozone-inflation-falls-more-than-expected-a-green-light-for-ecb-rate-cuts)
# The latest ECB projections indicated an annual average headline inflation of 2.3% in 2024, 2.0% in 2025, and 1.9% in 2026. However, there are rising risks associated with recent increases in oil ...
#
# 8. [CBI responds to inflation data - April 2024 | CBI - cbi.org.uk](https://www.cbi.org.uk/media-centre/articles/cbi-responds-to-the-latest-inflation-data-april-2024/)
# 17 April 2024. Alpesh Paleja, CBI Lead Economist, said: “While March’s fall in inflation was smaller than expected, it’s still likely to move closer to the Bank of England’s 2% target in the next few months. But the path beyond this will be bumpy – the CPI rate is likely to rise again in the second half of 2024, thanks to base effects ...
#
# 9. [2024 Euro Area Report - European Commission](https://economy-finance.ec.europa.eu/publications/2024-euro-area-report_en)
# The report underscores the importance of supporting the euro area's competitiveness with a focus on enhancing productivity, skills, innovation, and investment. This report provides the analytical underpinning for the 2024 euro area recommendation. Information and identifiers. Institutional Paper 259. November 2023. Brussels. PDF 52 pp. Tab. Graph.
#
# 10. [Inflation and price indices - Office for National Statistics](https://www.ons.gov.uk/economy/inflationandpriceindices)
# On a monthly basis, CPIH rose by 0.6% in February 2024, compared with a rise of 1.0% in February 2023. The Consumer Prices Index (CPI) rose by 3.4% in the 12 months to February 2024, down from 4.0% in January. Read this statistical bulletin.
#
# ## News Results:
# 11. [Focus turns to final March inflation for the Euro area](https://www.fxstreet.com/analysis/focus-turns-to-final-march-inflation-for-the-euro-area-202404170612)
# Today, focus is on the final inflation data for March in the euro area. We particularly look out for inflation components that reflect domestic demand as service inflation remained elevated in March.
#
# 12. [UK CPI inflation data ahead: Sterling hovering north of key support](https://www.fxstreet.com/analysis/uk-cpi-inflation-data-ahead-sterling-hovering-north-of-key-support-202404161905)
# Following today's mixed bag of employment and wages data, tomorrow’s attention is directed to the March UK CPI inflation release, scheduled to air at 7:00 am GMT+1.
#
# Address: bing: labor market reports USA Euro Area April 2024
# Title: labor market reports USA Euro Area April 2024 - Search
# Viewport position: Showing page 1 of 1.
# =======================
# A Bing search for 'labor market reports USA Euro Area April 2024' found 10 results:
#
# ## Web Results
# 1. [Labour Market Situation, OECD - Updated: April 2024 - OECD](https://search.oecd.org/employment/labour-market-situation-oecd-updated-april-2024.htm)
# In February 2024, the unemployment rate remained broadly stable at 4.9% in the OECD area, remaining below or at 5.0% since April 2022. The unemployment rate remained at record lows in the European Union (6.0%) and the euro area (6.5%). It was unchanged in 16 OECD countries with available data, while 6 countries recorded increases and another 10 ...
#
# 2. [U.S. Jobs & Labor Chart Pack: April 2024](https://pro.morningconsult.com/analyst-reports/u-s-jobs-labor-chart-pack-april-2024)
# The question is asked in over 40 countries, while this chart pack provides data on only the United States. Began fielding: Aug. 15, 2020; Frequency: Daily, typically reported as a 4-week moving average; Fielding period: 4 a.m. ET to 3 a.m. ET the following day; Sample size: Over 15,000 adults per day globally (over 5,000 per day in the United ...
#
# 3. [2024 Euro Area Report - European Commission](https://economy-finance.ec.europa.eu/publications/2024-euro-area-report_en)
# The report underscores the importance of supporting the euro area's competitiveness with a focus on enhancing productivity, skills, innovation, and investment. This report provides the analytical underpinning for the 2024 euro area recommendation. Information and identifiers. Institutional Paper 259. November 2023. Brussels. PDF 52 pp. Tab. Graph.
#
# 4. [Key Takeaways From The Job Market Report: April 2024](https://www.phenom.com/blog/navigating-job-market-trends-april-2024)
# 303,000. The report published for March 2024 reveals that total nonfarm payroll employment rose by 303,000, with notable gains in Healthcare, local and federal Government, Leisure and Hospitality, Construction, Social Assistance, and modest gains in Retail. The unemployment rate fell slightly to 3.8% as economists expected.
#
# 5. [Euro area unemployment at 6.4% - Eurostat - Die Europäische Kommission](https://ec.europa.eu/eurostat/en/web/products-euro-indicators/w/3-01032024-bp)
# Overview. In January 2024, the euro area seasonally-adjusted unemployment rate was 6.4%, down from 6.5% in December 2023 and from 6.6% in January 2023. The EU unemployment rate was 6.0% in January 2024, stable compared with December 2023 and down from 6.1% in January 2023. These figures are published by Eurostat, the statistical office of the European Union.
#
# 6. [ECB staff macroeconomic projections for the euro area, March 2024](https://www.ecb.europa.eu/press/projections/html/ecb.projections202403_ecbstaff~f2f2d34d5a.en.html)
# The euro area labour market (percentage of labour force (left-hand scale), annual percentage changes (right-hand scale)) ... (excluding the euro area), July 2021 for the United States, May 2021 for the euro area and April 2020 for both China and the United Kingdom. The latest observations are for 11 February 2024 (marine transit volumes), 26 ...
#
# 7. [2024 Euro Area Report](https://economy-finance.ec.europa.eu/system/files/2023-11/ip259_en.pdf)
# Overall, headline inflation is projected to decline in the euro. (1) European Commission, Business and consumer survey results, October 2023. area from 8.4% in 2022 to 5.6% in 2023, and then further down to 3.2% in 2024 and 2.2% in 2025.
#
# 8. [Europe Chart Pack (Apr. 2024) | Capital Economics](https://www.capitaleconomics.com/publications/europe-chart-pack/europe-chart-pack-apr-2024)
# Europe Chart Pack (Apr. 2024) 8th April 2024. The latest data are consistent with our view that the euro-zone will remain close to recession in the near term. With the labour market softening and inflation continuing to fall, the ECB is very likely to start cutting rates in June. Elsewhere, the SNB started loosening policy in March and we ...
#
# 9. [The euro area labour force: recent developments and drivers](https://www.ecb.europa.eu/press/economic-bulletin/focus/2023/html/ecb.ebbox202306_03~631ad61075.en.html)
# In recent years, an increasing share of newly employed in the euro area were previously inactive. Transitions from inactivity to employment (I-E transitions) were the main driver of the growth in employment. According to CES data, transitions from unemployment to employment (U-E transitions) accounted for 1.6% of total employment, whereas I-E ...
#
# 10. [Economic Bulletin Issue 1, 2024 - European Central Bank](https://www.ecb.europa.eu/press/economic-bulletin/html/eb202401.en.html)
# Eurostat’s flash estimate for January 2024, released after the cut-off date for this issue of the Economic Bulletin (24 January), saw headline inflation decreasing from 2.9% to 2.8%. See “ ECB Consumer Expectations Survey results – December 202 3”, press release, ECB, 6 February 2024.
#
# Address: bing: wage negotiations Germany France Spain Italy 2024
# Title: wage negotiations Germany France Spain Italy 2024 - Search
# Viewport position: Showing page 1 of 1.
# =======================
# A Bing search for 'wage negotiations Germany France Spain Italy 2024' found 10 results:
#
# ## Web Results
# 1. [Euro zone wage growth to peak early in 2024, path further ahead unclear ...](https://www.reuters.com/markets/europe/euro-zone-wage-growth-peak-early-2024-path-further-ahead-unclear-new-ecb-tracker-2024-02-09/)
# Often cited by ECB chief economist Philip Lane, the ECB's new tracker uses data from individual pay agreements in Germany, France, Italy, Spain, the Netherlands, Austria and Greece to estimate ...
#
# 2. [Euro zone wage growth to peak early in 2024, path further ahead unclear ...](https://uk.finance.yahoo.com/news/euro-zone-wage-growth-peak-112747683.html)
# "Negotiations over the first quarter of 2024 are likely to be decisive for the development of wage pressures over 2024," the authors of the paper wrote. Often cited by ECB chief economist Philip Lane, the ECB's new tracker uses data from individual pay agreements in Germany, France, Italy, Spain, the Netherlands, Austria and Greece to estimate wage pressures and gauge sentiment.
#
# 3. [Occasional Paper Series - European Central Bank](https://www.ecb.europa.eu/pub/pdf/scpops/ecb.op338~dd97c1f69e.en.pdf?a1270dd1c874c2ecc6aa6deaf61f1cb3)
# There is considerable uncertainty regarding the persistence of the current high negotiated wage growth rates. In the third quarter of 2023, the ECB’s indicator of year-on-year negotiated wage growth in the euro area reached 4.7% (4.1% excluding one-off payments), well above its long-term average of 1.8% since 2010.
#
# 4. [How do minimum wages compare across Europe in 2024?](https://www.euronews.com/business/2024/02/05/how-do-minimum-wages-compare-across-europe-in-2024)
# Minimum wages for EU countries vary widely, with gross monthly minimum wages currently ranging from €477 in Bulgaria to €2,571 per month in Luxembourg. The minimum wage is more than €2,000 ...
#
# 5. [Euro Area Outlook 2024: Fading Headwinds - Goldman Sachs](https://www.goldmansachs.com/intelligence/pages/gs-research/euro-area-outlook-2024-fading-headwinds/report.pdf)
# Looking across countries, we expect 0.6% in Germany, 1.1% in France, 0.7% in Italy and 1.7% in Spain. n Second, we expect underlying inﬂation to normalise in 2024. Core inﬂation has cooled more than expected in recent months—with sequential core inﬂation now running at around 2½%—and wage growth is showing clear signs of deceleration.
#
# 6. [Inflation and the response of public wages in the euro area](https://www.ecb.europa.eu/press/economic-bulletin/focus/2023/html/ecb.ebbox202305_08~37403a54da.en.html)
# After having generally grown at rates above inflation since the inception of the euro, public wages took a deep cut in real terms in 2022, but they are expected to partly recover over the projection horizon 2023-25 (Chart A). In the period 2001-21, euro area public wages and compensation per employee grew on average at an annual rate of 2.3%.
#
# 7. [Negotiated wages | ECB Data Portal - europa.eu](https://data.ecb.europa.eu/data/data-categories/prices-macroeconomic-and-sectoral-statistics/other-prices-and-costs/labour-costs/negotiated-wages)
# Neither seasonally nor working day adjus... Indicator of negotiated wage rates Total European Central Bank Annual rate of change. Show all. More geographical areas. 2006 to 2023. 4.47 (2023) Percentage change. Last updated: 20 Feb 2024 11:00 CET. STS.A.I9.N.INWR.000000.3.ANR.
#
# 8. [Negotiated pay rates and labour costs | Deutsche Bundesbank](https://www.bundesbank.de/en/statistics/economic-activity-and-prices/negotiated-pay-rates-and-labour-costs/negotiated-pay-rates-and-labour-costs-795514)
# The negotiated pay rate statistics of the Deutsche Bundesbank track the development of negotiated wages in all key sectors of the German economy. Data are derived from approximately 500 collective wage agreements and regulations on civil servant pay in around 40 sectors, comprising just under 20 million employees (wage earners, salaried ...
#
# 9. [Minimum wages 2024 – The tide is turning | European Foundation for the ...](https://www.eurofound.europa.eu/en/resources/article/2024/minimum-wages-2024-tide-turning)
# The situation in Italy is different, as the high inflation rate was not reflected in collective bargaining outcomes: with an inflation rate of 8.7%, salaries in Italy grew by only 2% during 2022. The contracts of 7.7 million workers in the private sector expired, leading to reductions in real wages.
#
# 10. [German wage restraint could endanger eurozone stability](https://www.euractiv.com/section/economy-jobs/news/german-wage-restraint-could-endanger-eurozone-stability/)
# A recent conclusion of wage negotiations in the German chemical industry saw a permanent increase of a meagre 3.25% in 2023 and 2024, respectively. ... 6 France, Germany and Italy eye ‘omnibus ...
#
# Address: bing: factors influencing EUR/USD exchange rate April 2024
# Title: factors influencing EUR/USD exchange rate April 2024 - Search
# Viewport position: Showing page 1 of 1.
# =======================
# A Bing search for 'factors influencing EUR/USD exchange rate April 2024' found 10 results:
#
# ## Web Results
# 1. [EUR/USD Monthly Forecast: April 2024 | Forex Factory](https://www.forexfactory.com/news/1276076-eurusd-monthly-forecast-april-2024)
# GDP numbers and inflation statistics last week in the U.S continued to show a rather stubbornly strong economy; even Consumer Sentiment numbers were higher than anticipated. While the Fed has seemingly promised a few interest rate cuts in 2024, economic data is not helping its case and doubts are being seen throughout global Forex as the USD ...
#
# 2. [Euro (EUR) to US Dollar (USD) Exchange Rates for April 8, 2024](https://www.exchange-rates.org/exchange-rate-history/eur-usd-2024-04-08)
# This chart shows EUR/USD exchange rate history data for 2024. The average EUR/USD exchange rate for 2024 is 1.0849 US Dollars per Euro. The highest EUR/USD exchange rate in 2024 was 1.1038 US Dollars per Euro on January 1, 2024. The lowest EUR/USD exchange rate in 2024 was 1.0627 US Dollars per Euro on April 15, 2024.
#
# 3. [EUR to USD Exchange Rate History for 2024](https://www.exchange-rates.org/exchange-rate-history/eur-usd-2024)
# 1 EUR = 1.0810 USD. 1 EUR = 1.0810 USD. Worst EUR to USD exchange rate in January 2024: €1 = $1.0810. Best EUR to USD exchange rate in January 2024: €1 = $1.1038. Average EUR to USD exchange rate in January 2024: €1 = $1.0909. February 2024.
#
# 4. [EUR/USD Monthly Forecast: April 2024 (Chart) - dailyforex.com](https://www.dailyforex.com/forex-technical-analysis/2024/03/eurusd-forecast-april-2024/210100)
# EUR/USD Monthly Forecast: April 2024. The EUR/USD will begin April’s trading near mid-term lows as financial institutions continue to show nervous behavioral sentiment regarding the outlook of U.S Federal Reserve policy. The EUR/USD went into this weekend near the 1.07895 level which will not make bullish traders happy, unless of course they ...
#
# 5. [Euro to Dollar (EURUSD) Forecast for 2024-2025 and Beyond - LiteFinance](https://www.litefinance.org/blog/analysts-opinions/eurusd-forecast-and-price-prediction/)
# Major takeaways. In the medium term, most analysts expect the EURUSD to grow to 1.1449 by the end of 2025. The rate can reach 1.296 before 2027 if an optimistic scenario plays out. It's worth noting that the euro price may fall below $1 while correcting. The currency pair's rate drops during market instability.
#
# 6. [Euro To Dollar FX Outlook: "A Weaker EUR/USD From ... - Exchange Rates UK](https://www.exchangerates.org.uk/news/40434/2024-04-01-euro-to-dollar-fx-outlook-a-weaker-eur-usd-from-here-credit-agricole.html)
# Euro to Dollar Exchange Rate Forecasts March 2020: 18 Currency Analysts' EUR/USD Technical Outlook, Opinion and Predictions The Euro US Dollar exchange rate is hovering around $1.11434 (-0.01%) on ...
#
# 7. [Euro to US Dollar Spot Exchange Rates for 2024](https://www.exchangerates.org.uk/EUR-USD-spot-exchange-rates-history-2024.html)
# Sunday 14 April 2024 (14/04/2024) €1 EUR = $1.0649. Euro rates for 14/04/2024. Lowest exchange rate in 2024: 1.0649 USD, Highest exchange rate in 2024: 1.1035 USD, Average exchange rate in 2024: ...
#
# 8. [Exploring Scenarios: EUR/USD Forecasts and Key Influencing Factors for 2024](https://www.fxmag.com/forex/exploring-scenarios-eur-usd-forecasts-and-key-influencing-factors-for-2024)
# The above forecasts of course are built on many core assumptions. Using the most liquid FX pair, EUR/USD as the benchmark for the FX market in general, we see a range of outcomes in the 0.88 to 1.21 region. If you think US inflation will not allow the Fed to cut, if you think a local recession and return of the Maastricht criteria sparks a ...
#
# 9. [Foreign Currency Trading Forecast for 2024: Analysis and Trends](https://blog.roboforex.com/blog/2024/02/09/foreign-currency-trading-forecast/)
# The quotes of the EUR/USD pair, which serves as a reference point for the currency market in general, are projected to hover within a wide range of 0.88-1.21. Possible scenarios of fluctuations in the pair’s exchange rate are outlined below: Forecasts for the EUR/USD exchange rate fluctuations in 2024 from ING Group GBP/USD
#
# 10. [EUR/USD Analysis Today 10/4: Bracing for Impact (Chart)](https://www.dailyforex.com/forex-technical-analysis/2024/04/eurusd-analysis-10-april-2024/210538)
# EUR/USD Technical Analysis and forecast: As mentioned before, the stability of the EUR/USD exchange rate near the psychological support level of 1.0800 will continue, supporting further bearish dominance in the trend. If the US dollar gains positive momentum from today's data, bears may push the currency pair towards stronger support levels, with the next targets being 1.0745, 1.0660, and 1. ...
#
# Address: bing: pricing of inflation swaps Eurozone USA April 2024
# Title: pricing of inflation swaps Eurozone USA April 2024 - Search
# Viewport position: Showing page 1 of 1.
# =======================
# A Bing search for 'pricing of inflation swaps Eurozone USA April 2024' found 10 results:
#
# ## Web Results
# 1. [Eurozone inflation eases: Trends across the continent and ECB rate ...](https://www.euronews.com/business/2024/04/17/eurozone-inflation-eases-trends-across-the-continent-and-ecb-rate-expectations)
# In March 2024, inflation in the euro area fell from 2.6% to 2.4%, as reported by Eurostat today, marking a four-month low and confirming preliminary data.
#
# 2. [Inflation in the euro area and the US - causes, persistence, outlook](https://www.ecb.europa.eu/press/key/date/2023/html/ecb.sp230420~661bd5928c.en.pdf)
# This factor inflated the September 2022 OFI deposits, being reversed in October and November 2022. “M1 deposits” are overnight deposits. “Other deposits” includes deposits other than time and M1 deposits. Bank bonds are those held by euro area residents excluding MFIs and central government.
#
# 3. [Euro zone inflation unexpectedly eases, boosting rate cut case](https://www.reuters.com/markets/europe/euro-zone-inflation-unexpectedly-eases-boosting-rate-cut-case-2024-04-03/)
# Underlying inflation, closely watched by the ECB to gauge the durability of price pressures, meanwhile fell to 2.9% from 3.1%, coming below expectations for 3.0%, data from Eurostat, the EU's ...
#
# 4. [Inflation undershoot to spark ECB rate-cutting in 2024](https://www.oxfordeconomics.com/wp-content/uploads/2023/11/Eurozone-Inflation-undershoot-to-spark-ECB-rate-cutting-in-2024.pdf?pi_content=6e84ebcd1dd4f2efb79b6d796ceb58bf1555d92620d6bb00e0ed3092be3b7239)
# In our baseline, inflation falls below 2% by mid-2024, which will trigger rate cuts by the ECB. The council may be reluctant initially, but if inflation is as low as we think in 2024-2025, a sustained cutting cycle will be needed to prevent a sharp rise in real interest rates. We expect rate cuts to commence in April 2024 and amount to 150bps ...
#
# 5. [Eurozone inflation undershoot to spark ECB rate-cutting in 2024](https://www.oxfordeconomics.com/resource/eurozone-inflation-undershoot-to-spark-ecb-rate-cutting-in-2024/)
# In our baseline, inflation falls below 2% by mid-2024, which will trigger rate cuts by the ECB. The council may be reluctant initially, but if inflation is as low as we think in 2024-2025, a sustained cutting cycle will be needed to prevent a sharp rise in real interest rates. We expect rate cuts to commence in April 2024 and amount to 150bps ...
#
# 6. [EUR/USD Price Forecast 2024: Will We See Parity?](https://au.investing.com/news/forex-news/eurusd-price-forecast-2024-will-we-see-parity-3204855)
# UBS cut its EUR/USD in a note dated April 17, now forecasting the pair to trade at 1.0500, from 1.1200, at the end of 2024, and at 1.0500, from 1.0900, at the end of the second quarter. “We suspect that as the ECB starts to cut rates while the Fed lags, the EUR will come under further pressure,” said analysts at the Swiss bank.
#
# 7. [Confirmed Euro Zone Inflation Fall Bolsters ECB's June Rate Cut Plan](https://money.usnews.com/investing/news/articles/2024-04-17/confirmed-euro-zone-inflation-fall-bolsters-ecbs-june-rate-cut-plan)
# Meanwhile underlying price growth, which filters out volatile food and energy prices dipped to 2.9% from 3.1%, despite services inflation holding steady at an uncomfortably high 4.0%.
#
# 8. [ECB leaves eurozone interest rates on hold but hints at cut this summer ...](https://www.theguardian.com/business/live/2024/apr/11/uk-interest-rate-cuts-bank-of-england-greene-us-inflation-european-central-bank-eurozone-business-live)
# In the meantime, there’s encouraging news on inflation from America. US producers raised their prices more slowly than expected last month, with the US PPI index only rising by 2.1% in March ...
#
# 9. [Eurozone inflation expectations and real rates - EFG](https://www.efginternational.com/insights/2022/eurozone-inflation-expectations-and-real-rates.html)
# The most reliable reference for market expectations for eurozone inflation is that derived from the inflation swaps market. 1 Chart 1 shows that since the early 2000s to the outbreak of the pandemic, inflation expectations declined. In 2014, medium to long term expectations fell below the ECB’s 2% target, a shift that convinced the ECB to restart and broaden its bond-buying program.
#
# 10. [Eurozone inflation hits 2-year low as US price pressures ease](https://www.ft.com/content/37b13644-5ed9-4caa-83a4-4f3094125d8e)
# Eurozone inflation hits 2-year low as US price pressures ease. Data helps steady bond markets and signals prospect of end to interest rate rises on both sides of Atlantic. Consumer prices in the ...
#
# --------------------------------------------------------------------------------
