# %%
from autosearch.functions.text_analysis import chunk_pdf

from autosearch.database.paper_database import PaperDatabase
from autosearch.analysis.document_analyzer import DocumentAnalyzer
from autosearch.research_project import ResearchProject

import autogen
from typing import List, Dict, Any

# %%
import os
from dotenv import load_dotenv
from azure.core.exceptions import HttpResponseError

# Load environment variables
load_dotenv()

# Retrieve Azure credentials from environment variables
config={
    'doc_api_key': os.getenv("DOCUMENT_INTELLIGENCE_KEY"),
    'doc_endpoint': os.getenv("DOCUMENT_INTELLIGENCE_ENDPOINT")
}

# %%
title = "Exploring the Intricacies of Polymer Representation: Unraveling Complexity"

# %%
test_project = ResearchProject(
    project_id = "project_test",
    version= "0.1",
    config=config,
    config_file="OAI_CONFIG_LIST-sweden-505",
    initiate_db= False,
    funcClsList = ["FactualCheck", "GetPDF", "GetPDFs", "UrlCheck", "ArxivRetriever", "ArxivSearch"],
    communiteList = ["outline_agents", "write_section_agents", "instructor_agents"]
)
project_config = test_project.ProjectConfig
print(project_config.logging_session_id)
test_project.run(title=title)
# Out:
# Logging session ID: fa569d16-418e-433f-95c1-71c77f59412d
#     Location = ./project_test/0.1/db/uid_text_dict.pkl
# Equipping function 'arxiv_retriever' to agent 'blog_editor-in-chief'
# Equipping function 'arxiv_search' to agent 'blog_editor-in-chief'
# Equipping function 'get_pdf' to agent 'blog_editor-in-chief'
# Equipping function 'get_pdfs' to agent 'blog_editor-in-chief'
# Equipping function 'factual_check' to agent 'content_strategist'
#     Location = ./project_test/0.1/db/uid_text_dict.pkl
# Equipping function 'factual_check' to agent 'content_review_specialist'
# Equipping function 'arxiv_retriever' to agent 'content_review_specialist'
# Equipping function 'arxiv_search' to agent 'content_review_specialist'
# Equipping function 'get_pdf' to agent 'content_review_specialist'
#     Location = ./project_test/0.1/db/uid_text_dict.pkl
# Equipping function 'arxiv_search' to agent 'topic_expert'
# Equipping function 'arxiv_retriever' to agent 'topic_expert'
#     Location = ./project_test/0.1/db/uid_text_dict.pkl
# Equipping function 'arxiv_search' to agent 'research_resource_expert'
# Equipping function 'arxiv_retriever' to agent 'research_resource_expert'
# Equipping function 'get_pdf' to agent 'research_resource_expert'
# /home/alibina/miniconda3/envs/autogen/lib/python3.12/site-packages/autogen/agentchat/conversable_agent.py:2409: UserWarning: Function 'arxiv_search' is being overridden.
#   warnings.warn(f"Function '{name}' is being overridden.", UserWarning)
# /home/alibina/miniconda3/envs/autogen/lib/python3.12/site-packages/autogen/agentchat/conversable_agent.py:2409: UserWarning: Function 'arxiv_retriever' is being overridden.
#   warnings.warn(f"Function '{name}' is being overridden.", UserWarning)
# fa569d16-418e-433f-95c1-71c77f59412d
# topic_expert (to chat_manager):
#
#
#         We need to create comprehensive instructions for the Editor-in-Chief to write an article titled:
#         "Exploring the Intricacies of Polymer Representation: Unraveling Complexity"
#
#         Each agent should contribute their expertise to craft a well-rounded instruction.
#         Topic Expert, please start by analyzing the title and providing key insights.
#
#
# --------------------------------------------------------------------------------
#
# Next speaker: structure_specialist
#
# structure_specialist (to chat_manager):
#
# Analyzing the title "Exploring the Intricacies of Polymer Representation: Unraveling Complexity," several key insights emerge:
#
# - The topic is specialized and technical, focusing on polymers which are large, complex molecules made from repeating subunits. This could attract a readership from fields such as chemistry, materials science, and engineering.
#
# - "Exploring the Intricacies" suggests that the article will delve into the detailed and nuanced aspects of how polymers are represented, potentially covering different models, notation systems, or techniques used to describe and visualize polymer structures.
#
# - "Unraveling Complexity" implies that there will be an element of clarification or simplification involved, making complex polymer structures more understandable or accessible.
#
# To effectively communicate these insights, the article would likely need to cover:
#
# - The foundational knowledge of polymer chemistry and why precise representation is vital for various applications (e.g., materials design, predictive modeling).
#
# - Detailed examination of the methods used to represent polymers, such as chemical notation and molecular modeling tools.
#
# - Current challenges in representing polymer complexity and how these challenges are addressed in scientific practice.
#
# Given this analysis, the structure of the article should address both the educational background on polymers and the more advanced technical methodologies used in their representation.
#
# --------------------------------------------------------------------------------
#
# Next speaker: audience_adaptation_expert
#
# audience_adaptation_expert (to chat_manager):
#
# From an audience adaptation perspective, the article "Exploring the Intricacies of Polymer Representation: Unraveling Complexity" can be more accessible by following these guidelines:
#
# 1. Explaining complex concepts in layman's terms:
# - Compare polymer molecules to something familiar, like a train with a series of identical or similar cars (monomers) linked together.
# - Describe polymer representations as a kind of elaborate blueprint or map, helping scientists to understand and predict the behavior and properties of these materials.
# - Use everyday language to explain concepts like molecular models, akin to using different scales of models to represent something that can't be seen with the naked eye, such as miniatures used in architecture.
#
# 2. Real-world examples or applications:
# - Discuss how different representations of polymers impact the development of everyday items like plastic bottles, clothing fibers, or car tires.
# - Explain the importance in the medical field, where understanding the polymer structure can lead to better materials for medical implants or drug delivery systems.
# - Illustrate with the creation of new materials, like biodegradable plastics and high-performance composites used in the aerospace industry, relying on understanding polymer structures.
#
# 3. Analogies to help readers understand difficult concepts:
# - Use the analogy of a language, with the polymer structure being the alphabet and the representation being different dialects or writing systems that can express the same ideas in diverse ways.
# - Compare molecular modeling to video game graphics, where both attempt to visualize something that isn't palpable in real life with the best approximation.
# - Equate the complexity of polymer representation with a jigsaw puzzle, where every piece (monomer) fits together to form a complete picture (polymer), and the representation helps to understand how the pieces connect.
#
# 4. Balancing technical depth with broader accessibility:
# - Introduce each technical term with a straightforward explanation and possibly provide a glossary for reference.
# - Use visuals, such as diagrams or infographics, to depict polymer structures and representations.
# - Alternate between more complex explanations and summaries to keep the article engaging for a broad audience while providing depth for those with more specialized interest.
# - Ensure that the introduction and conclusion are particularly accessible, as they are likely to be read by a wider audience.
#
# Incorporating these elements can make the article engaging not only for experts but also for curious non-specialists who are interested in the science of materials.
#
# --------------------------------------------------------------------------------
#
# Next speaker: research_resource_expert
# Add of existing embedding ID: 5
# Add of existing embedding ID: 58
# Add of existing embedding ID: 80
# Add of existing embedding ID: 93
# Add of existing embedding ID: 150
# Add of existing embedding ID: 155
# Add of existing embedding ID: 157
# Add of existing embedding ID: 161
# Add of existing embedding ID: 203
# Add of existing embedding ID: 236
# Add of existing embedding ID: 272
# Add of existing embedding ID: 309
# Add of existing embedding ID: 316
# Add of existing embedding ID: 323
# Add of existing embedding ID: 324
# Add of existing embedding ID: 330
# Add of existing embedding ID: 372
# Add of existing embedding ID: 380
# Add of existing embedding ID: 380
# Add of existing embedding ID: 386
# Add of existing embedding ID: 387
# Add of existing embedding ID: 391
# Add of existing embedding ID: 391
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# research_resource_expert (to chat_manager):
#
# As an Assistant, drawing from relevant aspects of the field of polymer representation, some pertinent suggestions for writing the article "Exploring the Intricacies of Polymer Representation: Unraveling Complexity” might include:
#
# 1. Statements that capture the essential nature and the broad impact of polymers and their representations.
# 2. The rationale for the need for different kinds of polymer representations, referencing both historical and cutting-edge techniques.
# 3. A discussion on the interplay between theoretical models and experimental practices in representing polymer structures and dynamics.
# 4. Insight into how polymer representation is crucial to the development and refinement of materials and their applications in various industries.
# 5. Presentation of emerging technologies and methodologies in the field, such as machine learning, and how they might transform our understanding and utilization of polymers.
# 6. Perspectives on the challenges faced in this area of research and potential ways to address them.
# 7. A forward-looking section on the future of polymer representation, touching upon interdisciplinary collaboration and innovation.
#
# Each of these content areas can be reinforced by incorporating expert insights, current research findings, and appropriate case studies. The article should maintain a balance of technical accuracy with accessibility to cater to both specialists and interested non-specialists. Visual aids, like charts, graphs, and 3D models, could greatly enhance the reader's comprehension of polymer structures and representations.
#
# --------------------------------------------------------------------------------
#
# Next speaker: instruction_synthesizer
#
# instruction_synthesizer (to chat_manager):
#
# FINAL INSTRUCTION:
#
# Title: "Exploring the Intricacies of Polymer Representation: Unraveling Complexity"
#
# Objective: To write an informative and engaging article that elucidates the complexity of polymer representation for both specialists and interested lay readers.
#
# Instruction:
#
# 1. **Introduction (300 words)**
#    - Provide an overview of polymers, their importance in science, technology, and industry.
#    - Introduce the concept of polymer representation and its significance.
#    - Briefly mention the structure of the article and what the reader can expect to learn.
#
# 2. **Foundational Knowledge (600 words)**
#    - Explain basic polymer chemistry and why precise representation matters.
#    - Describe different models and notation systems used in polymer representation.
#    - Use analogies and layman's terms to explain complex concepts.
#
# 3. **Methods of Representation (800 words)**
#    - Dive into various methods used to represent polymer structures, including chemical notation and molecular modeling tools.
#    - Discuss how different representations affect the understanding of polymer properties and applications.
#    - Integrate visual aids (diagrams, infographics) to illustrate complex ideas.
#
# 4. **Current Challenges (600 words)**
#    - Address the challenges scientists face in accurately representing complex polymer structures.
#    - Explore current solutions and methods for overcoming these challenges.
#    - Consider providing real-world examples to showcase the impact of these challenges.
#
# 5. **Technological Advances and Future Directions (700 words)**
#    - Highlight emerging technologies like machine learning and their role in advancing polymer representation.
#    - Speculate on future research directions and interdisciplinary collaboration possibilities.
#    - Discuss potential innovations and their implications for material sciences and industry applications.
#
# 6. **Conclusion (300 words)**
#    - Summarize the key points covered in the article.
#    - Emphasize the importance of polymer representation in advancing scientific understanding and technological developments.
#    - Provide a succinct overview of potential future developments and their societal impact.
#
# 7. **Additional Considerations:**
#    - Remember to keep a balance between technical depth and broader accessibility; use clear and concise explanations.
#    - Provide a glossary to define technical terms and ensure broader understanding.
#    - Ensure that the visual aids used are accurately labeled and contribute to the reader's comprehension of the topic.
#    - Make sure that the introduction and conclusion are accessible to a wider audience.
#
# Resources:
# - Draw upon current research findings, expert insights and possibly include brief interviews or quotes from leading researchers in the field.
# - Reference case studies that demonstrate practical applications of polymer representations.
#
# Article Guidelines:
# - Word Count: Approximately 3,300 words.
# - Audience: Scientists, engineers, and technically interested laypersons.
# - Citation Style: APA format for all citations and references.
# - Sections: Structured as outlined in the instruction.
# - Visual Aids: Include diagrams, infographics and 3D models, as necessary.
#
# END INSTRUCTION
#
# --------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 12
#      10 project_config = test_project.ProjectConfig
#      11 print(project_config.logging_session_id)
# ---> 12 test_project.run(title=title)
#
# File ~/repo/usecases/autosearch/src/autosearch/research_project.py:140, in ResearchProject.run(self, title)
#     138 blog_editor = None
#     139 for agent in self.agents_groups['outline_agents']:
# --> 140     if agent.name == "blog_editor-in-chief":
#     141         blog_editor = agent
#     142         break
#
# AttributeError: 'dict' object has no attribute 'name'

# %%
funcs.append(("write_section", write_section, "Write a section of a blog post based on a given title and brief."))

arg = [
    {
        "title": "Embracing Large Language Models (LLMs): A Preamble",
        "brief": "Discuss the scale, data training needs, and applications of LLMs across various industries. Highlight the critical importance of safety measures and the need for reliable performance.",
        "silent": True
        },
    ]

# %%
from autosearch.communities.outline_agents import agentsconfig
from autosearch.agents.agents_creator import AgentsCreator

agents = AgentsCreator(test_project.ProjectConfig, agents_config=agentsconfig).initialize_agents()
agents

# %%
blog_editor = agents[0]['blog_editor']
blog_editor.function_map

# %%
from autosearch.chat.outline_creator import OutlineCreator


outline_creator = OutlineCreator(test_project.ProjectConfig, agents)
outline_creator.run(message = task.format(topic=topic), 
                    messages = [],
                    silent = False,
                    )

# %%
tests = [
    ('factual_check', {
        "text": "The collaboration between these fields also birthed differentiable programming frameworks for quantum chemistry, like TorchANI and TensorMol [4]. These latter-day frameworks enable researchers to quickly prototype neural networks that learn quantum mechanical laws directly from data, providing a valuable tool to accelerate discovery. This integration has offered promising results in tasks like molecular dynamics simulations, which are key for understanding chemical reactions and material properties.", 
        "paper_title": "Automated Calculation of Thermal Rate Coefficients using Ring Polymer Molecular Dynamics and Machine-Learning Interatomic Potentials with Active Learning", 
        "paper_url": "http://arxiv.org/pdf/1805.11924v3", 
        "reason": "To confirm the factual information about differentiable programming frameworks and their impact on research in quantum chemistry and neural networks."
    }),
    ('get_pdfs', {
        "urls": ["http://arxiv.org/pdf/2305.13267v1", "http://arxiv.org/pdf/2305.06530v1"],
        "reasons": ['factual_check'] * 2
    }),
    ('get_pdf', {
        "url": "https://arxiv.org/pdf/2110.13711",
        "reason": "factual_check",
        "part": "full"
    }),
    ('url_check',{
            "paper_url": "https://arxiv.org/pdf/2107.03012.pdf",
            "paper_title": "From algebra to analysis: new proofs of theorems by Ritt and Seidenberg"
    }),
    ('arxiv_retriever',{
        "queries":["Large Language Models", "Assessing Language Models", "AI safety and reliability"],
        "n_results":3
    }),
    ('arxiv_search',{"query":"Human-Centred Learning Analytics and AI in Education: a Systematic Literature Review"}),
]

for fucn_name, args in tests:
    results = None
    for func in test_project.functions:
        if func.name == fucn_name:
            print(f"Running {fucn_name} with args: {args}")
            results = func.func(**args)
            print(results)
    
    if results is None:
        print(f"Function {fucn_name} not found")
        continue

# %%
func.get_function_details()

# %%
[func.name for func in test_project.functions]

# %%
# Usage example
config = {
    'doc_api_key': 'your_api_key',
    'doc_endpoint': 'your_endpoint',
    'manager': {
        'llm_config': {...},
        'is_termination_msg': lambda x: 'TERMINATE' in x.get('content', '')
    },
    'agent_configs': {
        'outline': [
            {
                'name': 'editor',
                'system_message': '...',
                'llm_config': {...},
                'teach_config': {...},
                'functions': {
                    'arxiv_retriever': arxiv_retriever,
                    'arxiv_search': arxiv_search
                }
            },
            {
                'name': 'critic',
                'system_message': '...',
                'llm_config': {...},
                'teach_config': {...},
                'functions': {
                    'factual_check': factual_check
                }
            }
        ],
        'writing': [...],  # Similar structure for writing agents
        'compiling': [...]  # Similar structure for compiling agents
    }
}

project = ResearchProject("polymer_rep", "0.0.2", 
                          "Exploring the Intricacies of Polymer Representation: Unraveling Complexity", 
                          config)
blog_post = project.run()

# Save the blog post
with open(f'{project.db.project_dir}/blog_post.md', 'w') as f:
    f.write(blog_post)
