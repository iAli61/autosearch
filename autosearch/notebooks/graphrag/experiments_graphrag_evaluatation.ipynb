# %%
import nest_asyncio
nest_asyncio.apply()

import autogen
import json
import pandas as pd
import concurrent.futures
from datetime import datetime
from typing import Union, List, Dict

# %%
questions = [
"""
Create a comprehensive table comparing representation learning models for polymers. Include the following information for each model:

Model name
Year introduced
Key authors/research group
Type of representation (e.g., graph-based, sequence-based, 3D structure-based)
Input features used
Dimensionality of the learned representation
Training data type and size
Key applications (e.g., property prediction, polymer design)
Notable advantages
Limitations or challenges

After the table, provide a brief analysis (2-3 paragraphs) of the current trends in polymer representation learning, highlighting the most promising approaches and areas for future research. Please cite relevant papers for each model and in your analysis.
""",
"""
Create a comparative analysis of machine learning models used for predicting glass transition temperature (Tg) and melting temperature (Tm) of polymers. Include the following in your analysis:

A table comparing at least 5 different models, with the following information for each:
a) Model name and type (e.g., Random Forest, Neural Network, etc.)
b) Year introduced
c) Key authors/research group
d) Input features or representation used
e) Dataset size and composition
f) Accuracy metrics for Tg prediction (e.g., R², RMSE, MAE)
g) Accuracy metrics for Tm prediction (e.g., R², RMSE, MAE)
h) Computational complexity or training time (if available)
A brief discussion (2-3 paragraphs) on:
a) The overall trends in prediction accuracy for Tg vs Tm
b) Factors that contribute to higher accuracy in certain models
c) Challenges in predicting these properties accurately
d) Recent advancements or novel approaches in the field
A short section on potential areas for improvement and future research directions.

Please provide citations for the models and studies mentioned in your analysis.
"""
]

models = ['gpt-4', 'gpt-4o', 'gpt-4o-mini', 'gpt-35-turbo', 'gpt-35-turbo-16k']

# input_dir = '/home/azureuser/autogen_uscases/graphrag_memo/output/20240830-145930/artifacts'
input_dir = '/home/azureuser/autogen_uscases/autosearch/notebooks/graphrag/output/20240903-050706/artifacts'
# input_dir = '/home/azureuser/autogen_uscases/graphrag_memo/output/20240830-145930/artifacts'
lancedb_uri = "/home/azureuser/autogen_uscases/autosearch/notebooks/graphrag/output/20240903-050706/artifacts/lancedb"
embedding_model = 'text-embedding-3-small'

# %%
config_list = autogen.config_list_from_json(
    "../OAI_CONFIG_LIST-sweden-505",
    file_location=".",
    filter_dict={
        "model": ["gpt-4"]
    },
)

llm_config = {
    "config_list": config_list,
    "timeout": 120,
}

# Create the GPT-4 agent
gpt4_agent = autogen.AssistantAgent(
    name="gpt4_evaluator",
    llm_config=llm_config
)

# Create a user proxy agent
user_proxy = autogen.UserProxyAgent(
    name="user_proxy",
    human_input_mode="NEVER",
    max_consecutive_auto_reply=10,
    is_termination_msg=lambda x: x.get("content", "").rstrip().endswith("TERMINATE"),
    code_execution_config=False,
)

# The create_evaluation_prompt, parse_evaluation_table, is_header_or_separator_row, and parse_score functions remain the same
def create_evaluation_prompt(result: Dict) -> str:
    prompt = f"""
    Evaluate and compare the following search results for the question: "{result['question']}"
    
    Model used: {result['model']}
    
    Local search result:
    {result['local_result']}
    
    Global search result:
    {result['global_result']}
    
    Please provide a detailed evaluation considering the following criteria:
    1. Relevance: How well does each result address the question?
    2. Completeness: Which result provides more comprehensive information?
    3. Accuracy: Are there any apparent errors or inconsistencies in either result?
    4. Clarity: Which result is easier to understand?
    5. Unique insights: Does either result provide unique information not present in the other?
    6. Coherence: How well-structured and logically connected is the information in each result?
    7. Source diversity: Does the result appear to draw from a variety of sources or perspectives?
    
    For each criterion, provide a brief explanation of your reasoning, followed by a score for both Local and Global results on a scale of 1-10.
    
    After your analysis, provide an overall score for each result, taking into account all the above criteria.
    
    Finally, conclude with a brief statement on which result (Local or Global) you think is better for this particular question and why.
    
    At the end of your analysis, provide a structured table with all the numerical scores using the following format:

    EVALUATION TABLE
    | Criterion        | Local Score | Global Score |
    |------------------|-------------|--------------|
    | Relevance        |             |              |
    | Completeness     |             |              |
    | Accuracy         |             |              |
    | Clarity          |             |              |
    | Unique Insights  |             |              |
    | Coherence        |             |              |
    | Source Diversity |             |              |
    | Overall          |             |              |

    Fill in the table with your numerical scores, ensuring all scores are between 1 and 10.

    End your evaluation with the word TERMINATE.
    """
    return prompt

import math
import re

def parse_evaluation_table(evaluation: str) -> Dict[str, Dict[str, float]]:
    try:
        table_text = evaluation.split("EVALUATION TABLE")[1].split("TERMINATE")[0].strip()
        lines = table_text.split("\n")
        scores = {}
        for line in lines:
            parts = [part.strip() for part in line.split("|") if part.strip()]
            if len(parts) >= 3 and not is_header_or_separator_row(parts):
                criterion = parts[0].lower().replace(" ", "_")
                try:
                    local_score = parse_score(parts[-2])  # Second to last part
                    global_score = parse_score(parts[-1])  # Last part
                    scores[criterion] = {"local": local_score, "global": global_score}
                except ValueError as e:
                    print(f"Warning: {str(e)} for criterion {criterion}")
        
        if not scores:
            raise ValueError("No valid scores found in the evaluation table")
        
        return scores
    except Exception as e:
        print(f"Error parsing evaluation table: {str(e)}")
        return {}

def is_header_or_separator_row(parts: List[str]) -> bool:
    # Check if it's a header row
    if any(header.lower() in " ".join(parts).lower() for header in ["criterion", "local score", "global score"]):
        return True
    
    # Check if it's a separator row (contains only dashes, possibly with colons for alignment)
    if all(re.match(r'^[-:]+$', part) for part in parts):
        return True
    
    return False

def extract_score(score_dict: Dict[str, str], model_name: str) -> Union[float, None]:
    # Normalize the model name
    model_name_lower = model_name.lower()
    
    # Define possible column names
    possible_names = [
        f"{model_name} Score",
        model_name,
        f"{model_name_lower} score",
        "Local Score" if "local" in model_name_lower else "Global Score"
    ]
    
    # Try to find a matching key
    for name in possible_names:
        if name in score_dict:
            return parse_score_value(score_dict[name])
    
    # If no exact match, try partial matches
    for key in score_dict.keys():
        if model_name_lower in key.lower():
            return parse_score_value(score_dict[key])
    
    # If still no match, return None
    return None

def parse_score_value(value: str) -> Union[float, None]:
    # Remove any asterisks or other non-numeric characters
    clean_value = re.sub(r'[^0-9./NA]', '', value.upper())
    
    if clean_value in ['NA', 'N/A', '']:
        return None
    elif '/' in clean_value:  # Handle fractional scores
        num, denom = clean_value.split('/')
        return float(num) / float(denom)
    elif '.' in clean_value:  # Handle decimal scores
        return float(clean_value)
    elif clean_value.isdigit():  # Handle integer scores
        return float(clean_value)
    else:
        # If it's a complex string (e.g., "1 (approx.)"), try to extract the first number
        match = re.search(r'\d+(\.\d+)?', value)
        if match:
            return float(match.group())
        else:
            return None 
    
    
def evaluate_single_result(result: Dict) -> Dict:
    print("=============================================")
    print(f"Evaluating question: {result['question']}, model: {result['model']}")
    print("=============================================")
    prompt = create_evaluation_prompt(result)
    
    user_proxy.initiate_chat(
        gpt4_agent,
        message=prompt,
    )
    
    evaluation = user_proxy.last_message()["content"]
    
    scores = parse_evaluation_table(evaluation)
    
    if not scores:
        print(f"Warning: Failed to parse scores for question: {result['question']}, model: {result['model']}")
        scores = {criterion: {"local": 0, "global": 0} for criterion in 
                  ["relevance", "completeness", "accuracy", "clarity", "unique_insights", "coherence", "source_diversity", "overall"]}
    
    return {
        "question": result["question"],
        "model": result["model"],
        "local_result": result["local_result"],
        "global_result": result["global_result"],
        "prompt": prompt,
        "evaluation": evaluation,
        "scores": scores
    }

def evaluate_results(results: Union[List[Dict], pd.DataFrame]) -> pd.DataFrame:
    evaluations = []
    
    def evaluate_and_store(result: Dict) -> None:
        evaluation = evaluate_single_result(result)
        evaluations.append(evaluation)
    
    # Convert to DataFrame if it's a list
    if isinstance(results, list):
        results_df = pd.DataFrame(results)
    else:
        results_df = results
    
    with concurrent.futures.ThreadPoolExecutor(max_workers=1) as executor:
        futures = [executor.submit(evaluate_and_store, row.to_dict()) for _, row in results_df.iterrows()]
        concurrent.futures.wait(futures)
    
    # Convert evaluations to DataFrame
    eval_df = pd.DataFrame(evaluations)
    
    # Expand the scores dictionary into separate columns
    score_df = pd.json_normalize(eval_df['scores'])
    score_df.columns = [f'score_{col}' for col in score_df.columns]
    
    # Combine the evaluation DataFrame with the scores DataFrame
    eval_df = pd.concat([eval_df.drop(columns=['scores']), score_df], axis=1)
    
    return eval_df

# %%
results_json = 'results-20240830-145930.json'
results = pd.read_json(results_json)

# Run the evaluation
evaluations_df = evaluate_results(results)

# Generate a unique filename with timestamp
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
filename = f'evaluations_{timestamp}.csv'

# Save the evaluations to a new CSV file
evaluations_df.to_csv(filename, index=False)

print(f"Evaluations completed and saved to {filename}")

# If you still want to save as JSON
json_filename = f'evaluations_{timestamp}.json'
evaluations_df.to_json(json_filename, orient='records', indent=4)
print(f"Evaluations also saved as JSON to {json_filename}")
# Out:
# =============================================
# Evaluating question:
# Create a comprehensive table comparing representation learning models for polymers. Include the following information for each model:
#
# Model name
# Year introduced
# Key authors/research group
# Type of representation (e.g., graph-based, sequence-based, 3D structure-based)
# Input features used
# Dimensionality of the learned representation
# Training data type and size
# Key applications (e.g., property prediction, polymer design)
# Notable advantages
# Limitations or challenges
#
# After the table, provide a brief analysis (2-3 paragraphs) of the current trends in polymer representation learning, highlighting the most promising approaches and areas for future research. Please cite relevant papers for each model and in your analysis.
# , model: gpt-4
# =============================================
# user_proxy (to gpt4_evaluator):
#
#
#     Evaluate and compare the following search results for the question: "
# Create a comprehensive table comparing representation learning models for polymers. Include the following information for each model:
#
# Model name
# Year introduced
# Key authors/research group
# Type of representation (e.g., graph-based, sequence-based, 3D structure-based)
# Input features used
# Dimensionality of the learned representation
# Training data type and size
# Key applications (e.g., property prediction, polymer design)
# Notable advantages
# Limitations or challenges
#
# After the table, provide a brief analysis (2-3 paragraphs) of the current trends in polymer representation learning, highlighting the most promising approaches and areas for future research. Please cite relevant papers for each model and in your analysis.
# "
#
#     Model used: gpt-4
#
#     Local search result:
#     Unfortunately, the data tables required to create such a comprehensive table and analysis are not provided. Without access to specific information about various representation learning models for polymers, including their introduction year, key authors, type of representation, input features, dimensionality, training data, applications, advantages, and limitations, I am unable to generate the requested table or provide an analysis of current trends in polymer representation learning.
#
# To create such a table and provide a meaningful analysis, one would typically need to conduct a thorough literature review of published research papers in the field of polymer informatics and machine learning. This would involve collecting data from various studies that detail the development and application of different polymer representation learning models.
#
# If you can provide the necessary data or access to relevant research papers, I would be happy to assist in creating the table and providing an analysis based on that information.
#
#     Global search result:
#     I am sorry but I am unable to answer this question given the provided data.
#
#     Please provide a detailed evaluation considering the following criteria:
#     1. Relevance: How well does each result address the question?
#     2. Completeness: Which result provides more comprehensive information?
#     3. Accuracy: Are there any apparent errors or inconsistencies in either result?
#     4. Clarity: Which result is easier to understand?
#     5. Unique insights: Does either result provide unique information not present in the other?
#     6. Coherence: How well-structured and logically connected is the information in each result?
#     7. Source diversity: Does the result appear to draw from a variety of sources or perspectives?
#
#     For each criterion, provide a brief explanation of your reasoning, followed by a score for both Local and Global results on a scale of 1-10.
#
#     After your analysis, provide an overall score for each result, taking into account all the above criteria.
#
#     Finally, conclude with a brief statement on which result (Local or Global) you think is better for this particular question and why.
#
#     At the end of your analysis, provide a structured table with all the numerical scores using the following format:
#
#     EVALUATION TABLE
#     | Criterion        | Local Score | Global Score |
#     |------------------|-------------|--------------|
#     | Relevance        |             |              |
#     | Completeness     |             |              |
#     | Accuracy         |             |              |
#     | Clarity          |             |              |
#     | Unique Insights  |             |              |
#     | Coherence        |             |              |
#     | Source Diversity |             |              |
#     | Overall          |             |              |
#
#     Fill in the table with your numerical scores, ensuring all scores are between 1 and 10.
#
#     End your evaluation with the word TERMINATE.
#
#
# --------------------------------------------------------------------------------
# gpt4_evaluator (to user_proxy):
#
# To evaluate the search results provided, we'll follow your criteria and provide a detailed assessment accordingly:
#
# 1. **Relevance**: The Local search acknowledges the complexity of the request and gives a reasonable explanation for why it cannot provide the output, namely the lack of direct data or access to papers. The Global search simply states inability without acknowledgment of the nature of the task. The Local search at least sets the stage for what is needed to answer the question, making it slightly more relevant.
#     - Local Score: 5
#     - Global Score: 3
#
# 2. **Completeness**: Both results fail to provide the requested comprehensive table or a detailed analysis. However, the Local result goes a step further by describing the typical process needed to create such a table. This shows an understanding of the task despite not completing it.
#     - Local Score: 4
#     - Global Score: 2
#
# 3. **Accuracy**: Both responses are accurate in stating that they are unable to complete the task without additional data. There are no apparent errors or inconsistencies since neither provided factual content to evaluate.
#     - Local Score: 10
#     - Global Score: 10
#
# 4. **Clarity**: The Local search result is more articulate in describing the limitations it faces, using clearer language to explain why the task couldn't be completed. This makes the expectation more transparent for the user. The Global result has less explanatory depth.
#     - Local Score: 7
#     - Global Score: 4
#
# 5. **Unique Insights**: Neither result provides unique insights into the field of polymer representation learning. Both acknowledge the limitation in answering due to lack of data. However, the Local result at least hints at the complexity and the research process involved.
#     - Local Score: 3
#     - Global Score: 1
#
# 6. **Coherence**: The Local result seems to be more coherent by guiding the user through why the search could not be completed and what would be necessary to do so. The Global result lacks this structure.
#     - Local Score: 6
#     - Global Score: 2
#
# 7. **Source Diversity**: Neither search result provides information drawn from sources or perspectives since they both admit to the inability to perform the task without external research data.
#     - Local Score: 1
#     - Global Score: 1
#
# Before assigning an overall score, I'll summarize the strengths of the Local result—it communicated the limitations in a clear and structured manner, briefly indicating the steps needed to gather such information, which suggests a higher degree of responsiveness to the user's needs.
#
# Given the criteria and explanations, the overall score reflects the Local result's superior communication and effort to guide the user despite both results being ultimately unable to provide the requested information.
#
# - Overall Local Score: 5
# - Overall Global Score: 3
#
# In conclusion, the Local result is better for this particular question because it communicates more effectively, providing an explanation for its limitations and indicating next steps. It shows a slightly higher level of engagement with the task at hand, even if it cannot be completed without further data.
#
# Here is the completed evaluation table:
#
# EVALUATION TABLE
# | Criterion        | Local Score | Global Score |
# |------------------|-------------|--------------|
# | Relevance        | 5           | 3            |
# | Completeness     | 4           | 2            |
# | Accuracy         | 10          | 10           |
# | Clarity          | 7           | 4            |
# | Unique Insights  | 3           | 1            |
# | Coherence        | 6           | 2            |
# | Source Diversity | 1           | 1            |
# | Overall          | 5           | 3            |
#
# TERMINATE
#
# --------------------------------------------------------------------------------
# =============================================
# Evaluating question:
# Create a comparative analysis of machine learning models used for predicting glass transition temperature (Tg) and melting temperature (Tm) of polymers. Include the following in your analysis:
#
# A table comparing at least 5 different models, with the following information for each:
# a) Model name and type (e.g., Random Forest, Neural Network, etc.)
# b) Year introduced
# c) Key authors/research group
# d) Input features or representation used
# e) Dataset size and composition
# f) Accuracy metrics for Tg prediction (e.g., R², RMSE, MAE)
# g) Accuracy metrics for Tm prediction (e.g., R², RMSE, MAE)
# h) Computational complexity or training time (if available)
# A brief discussion (2-3 paragraphs) on:
# a) The overall trends in prediction accuracy for Tg vs Tm
# b) Factors that contribute to higher accuracy in certain models
# c) Challenges in predicting these properties accurately
# d) Recent advancements or novel approaches in the field
# A short section on potential areas for improvement and future research directions.
#
# Please provide citations for the models and studies mentioned in your analysis.
# , model: gpt-4
# =============================================
# user_proxy (to gpt4_evaluator):
#
#
#     Evaluate and compare the following search results for the question: "
# Create a comparative analysis of machine learning models used for predicting glass transition temperature (Tg) and melting temperature (Tm) of polymers. Include the following in your analysis:
#
# A table comparing at least 5 different models, with the following information for each:
# a) Model name and type (e.g., Random Forest, Neural Network, etc.)
# b) Year introduced
# c) Key authors/research group
# d) Input features or representation used
# e) Dataset size and composition
# f) Accuracy metrics for Tg prediction (e.g., R², RMSE, MAE)
# g) Accuracy metrics for Tm prediction (e.g., R², RMSE, MAE)
# h) Computational complexity or training time (if available)
# A brief discussion (2-3 paragraphs) on:
# a) The overall trends in prediction accuracy for Tg vs Tm
# b) Factors that contribute to higher accuracy in certain models
# c) Challenges in predicting these properties accurately
# d) Recent advancements or novel approaches in the field
# A short section on potential areas for improvement and future research directions.
#
# Please provide citations for the models and studies mentioned in your analysis.
# "
#
#     Model used: gpt-4
#
#     Local search result:
#     # Comparative Analysis of Machine Learning Models for Polymer Property Prediction
#
# ## Table of Comparative Analysis
#
# | Model Name and Type | Year | Key Authors/Group | Input Features | Dataset Size | Tg Prediction Accuracy | Tm Prediction Accuracy | Computational Complexity |
# |---------------------|------|-------------------|----------------|--------------|------------------------|------------------------|--------------------------|
# | MPNN/Polymer Graph  | 2021 | Tao, L. et al.    | Polymer Graph  | Not specified| RMSE: 27°C             | Not specified          | Not specified            |
# | MPNN/Monomer Graph  | 2021 | Tao, L. et al.    | Monomer Graph  | Not specified| RMSE: 62°C             | Not specified          | Not specified            |
# | polyBERT            | 2021 | Chen, G. et al.   | Chemical Language Processing | Not specified | Not specified | Not specified | Not specified |
# | RF Model            | 2019 | Pilania, G. et al.| Count Fingerprints | Not specified | Not specified | Not specified | Not specified |
# | polyGNN             | 2021 | Tao, L. et al.    | Graph Neural Network | Not specified | Not specified | Not specified | Not specified |
#
# [Data: Relationships (3554, 3555, 1040, 3854, 1294); Entities (7008, 8267, 57, 14261, 155)]
#
# ## Discussion
#
# ### Trends in Prediction Accuracy
# The overall trends in prediction accuracy for Tg and Tm are not fully detailed in the provided data. However, it is noted that the MPNN/Polymer Graph model significantly outperforms the MPNN/Monomer Graph model in predicting Tg, with a much lower RMSE of 27°C compared to 62°C [Data: Relationships (3554, 3555)]. This suggests that polymer graph representations, which consider the entire polymer structure, may offer more accurate predictions than those based on monomer units alone.
#
# ### Factors Contributing to Higher Accuracy
# Factors contributing to higher accuracy in certain models include the complexity and specificity of the input features or representations used. For instance, the polymer graph representation captures more detailed structural information than the monomer graph, leading to more accurate Tg predictions [Data: Relationships (3554, 3555)]. Additionally, models like polyBERT, which utilize advanced chemical language processing techniques, may also capture nuanced structural information that can improve prediction accuracy [Data: Entities (9056)].
#
# ### Challenges in Prediction
# Challenges in accurately predicting Tg and Tm include the inherent complexity of polymer structures and the need for large, diverse datasets to train the models. The variability in polymer properties due to factors like chain length, cross-linking, and side groups adds to the difficulty of making accurate predictions [Data: Entities (137)].
#
# ### Recent Advancements
# Recent advancements in the field include the development of graph neural network-based models like polyGNN and the application of chemical language processing models like polyBERT. These models represent novel approaches that leverage the detailed structural information of polymers for improved property prediction [Data: Entities (9056); Relationships (1040, 1294)].
#
# ## Future Research Directions
#
# Potential areas for improvement and future research directions include the development of more sophisticated models that can handle the vast diversity of polymer structures. Enhancing the quality and size of datasets, including more diverse polymer types and incorporating experimental uncertainties, could also improve model robustness and accuracy. Additionally, exploring the impact of polymer processing conditions on Tg and Tm and integrating this information into predictive models could be a valuable research avenue. Finally, the application of transfer learning and active learning strategies could help in efficiently utilizing available data and refining models as new data becomes available.
#
# Citations:
# - Tao, L., Varshney, V., & Li, Y. (2021). Benchmarking Machine Learning Models for Polymer Informatics: An Example of Glass Transition Temperature. J. Chem. Inf. Model., 61, 5395-5413.
# - Chen, G., Tao, L., & Li, Y. (2021). Predicting Polymers’ Glass Transition Temperature by a Chemical Language Processing Model. Polymers, 13, 1898.
# - Pilania, G., Iverson, C. N., Lookman, T., & Marrone, B. L. (2019). Machine-Learning-Based Predictive Modeling of Glass Transition Temperatures: A Case of Polyhydroxyalkanoate Homopolymers and Copolymers. J. Chem. Inf. Model., 59, 5013-5025.
#
#     Global search result:
#     Unfortunately, the provided reports do not contain sufficient information to create a comparative analysis of machine learning models used for predicting glass transition temperature (Tg) and melting temperature (Tm) of polymers. The reports do not include specific details about different models, their introduction years, key authors, input features, dataset compositions, accuracy metrics, or computational complexities.
#
# However, I can provide a brief discussion on potential areas for improvement and future research directions in the field of computational polymer science, which may be relevant to the topic of machine learning models for predicting Tg and Tm.
#
# ### Potential Areas for Improvement and Future Research Directions
#
# The field of computational polymer science is rapidly evolving, and there are several areas where future research could lead to significant advancements. One such area is the integration of machine learning techniques with polymer databases. Machine learning algorithms can analyze vast amounts of data to uncover patterns and relationships that may not be immediately apparent to researchers. By combining these techniques with comprehensive polymer databases, it may be possible to improve the accuracy of predictive models for Tg and Tm [Data: Reports (3082, 891, 2090)].
#
# Another promising direction is the advancement of polymer fingerprinting methods. These methods involve creating unique identifiers for polymers based on their molecular or structural characteristics. Improved fingerprinting can enhance the ability of machine learning models to accurately predict properties like Tg and Tm by providing more detailed and discriminative input features.
#
# Lastly, the development of more sophisticated field-theoretic simulations could provide deeper insights into the behavior of polymers at the molecular level. These simulations take into account the complex interactions between polymer chains and their environment, which are crucial for understanding how polymers will behave under different conditions. Enhancements in simulation techniques could lead to more accurate models for predicting polymer properties, including Tg and Tm.
#
# In conclusion, while the specific details required for a comparative analysis of machine learning models for Tg and Tm prediction are not available in the reports, the field of computational polymer science is poised for significant advancements through the integration of machine learning, improved fingerprinting methods, and advanced simulations. These developments will likely address current challenges and contribute to higher accuracy in predictive models for polymer properties.
#
#     Please provide a detailed evaluation considering the following criteria:
#     1. Relevance: How well does each result address the question?
#     2. Completeness: Which result provides more comprehensive information?
#     3. Accuracy: Are there any apparent errors or inconsistencies in either result?
#     4. Clarity: Which result is easier to understand?
#     5. Unique insights: Does either result provide unique information not present in the other?
#     6. Coherence: How well-structured and logically connected is the information in each result?
#     7. Source diversity: Does the result appear to draw from a variety of sources or perspectives?
#
#     For each criterion, provide a brief explanation of your reasoning, followed by a score for both Local and Global results on a scale of 1-10.
#
#     After your analysis, provide an overall score for each result, taking into account all the above criteria.
#
#     Finally, conclude with a brief statement on which result (Local or Global) you think is better for this particular question and why.
#
#     At the end of your analysis, provide a structured table with all the numerical scores using the following format:
#
#     EVALUATION TABLE
#     | Criterion        | Local Score | Global Score |
#     |------------------|-------------|--------------|
#     | Relevance        |             |              |
#     | Completeness     |             |              |
#     | Accuracy         |             |              |
#     | Clarity          |             |              |
#     | Unique Insights  |             |              |
#     | Coherence        |             |              |
#     | Source Diversity |             |              |
#     | Overall          |             |              |
#
#     Fill in the table with your numerical scores, ensuring all scores are between 1 and 10.
#
#     End your evaluation with the word TERMINATE.
#
#
# --------------------------------------------------------------------------------
# gpt4_evaluator (to user_proxy):
#
# Here is the detailed evaluation based on the given criteria:
#
# 1. **Relevance**:
#    - The Local result addresses the question directly by providing a comparative table of different machine learning models, discussing trends and factors affecting prediction accuracies, challenges, and future research directions. It also includes citations which are very relevant to the given task.
#    - The Global result acknowledges the lack of specific information for comparative analysis and instead offers a general discussion of future research directions which only tangentially relate to the original question.
#    - **Local Score**: 9
#    - **Global Score**: 3
#
# 2. **Completeness**:
#    - The Local result provides specific details on models, albeit with some missing data points. It gives a more comprehensive response in line with the requested comparative analysis.
#    - The Global result lacks detailed information about the models and primarily discusses potential improvements in the field without providing the analysis required by the question.
#    - **Local Score**: 8
#    - **Global Score**: 2
#
# 3. **Accuracy**:
#    - Both results are taken at face value as accurate since no external verification is provided in this evaluation. The Local result appears more specific and relevant to the query, but without the dataset size or a complete set of accuracy metrics, it's hard to verify accuracy beyond what's given.
#    - With the Global result, the lack of specific details about models diminishes the potential for factual inaccuracies but also limits the response's utility.
#    - **Local Score**: 7 (due to incomplete data points)
#    - **Global Score**: 5 (no specific inaccuracies but also not much information to assess)
#
# 4. **Clarity**:
#    - The Local result is well-structured, with clear segmentation of information and a table format that facilitates understanding. Discussion points are well-articulated and easy to follow.
#    - The Global result is also clear and well-written, but the abstract nature of the content means it is less concrete and direct in relation to the question asked.
#    - **Local Score**: 9
#    - **Global Score**: 6
#
# 5. **Unique Insights**:
#    - The Local result provides unique insights into the specific models used for Tg and Tm predictions, citing actual data and references.
#    - The Global result discusses broader aspects of computational polymer science which, while insightful, are not unique or specific to the question.
#    - **Local Score**: 8
#    - **Global Score**: 3
#
# 6. **Coherence**:
#    - The information in the Local result is well-structured with logical connections between the table and the subsequent discussion.
#    - The Global result, while coherent within itself, does not provide the logical connection to the specific task of comparing machine learning models for Tg and Tm prediction.
#    - **Local Score**: 9
#    - **Global Score**: 5
#
# 7. **Source Diversity**:
#    - The Local result cites specific studies seemingly from a scientific domain, suggesting a good range of sources within that scope.
#    - The Global result does not cite specific sources, and the lack of information makes it difficult to assess the diversity of sources.
#    - **Local Score**: 7
#    - **Global Score**: 2
#
# Considering all the above criteria, the overall scores are as follows:
#
# 8. **Overall**:
#    - **Local Score**: 8.1 (Average of individual scores)
#    - **Global Score**: 3.7 (Average of individual scores)
#
# The Local result is better for this particular question because it directly addresses the question with specific information, structured data presentation, and citations. Although some information is missing, the Local result is far more aligned with the original query and provides concrete data for comparison.
#
# EVALUATION TABLE
# | Criterion        | Local Score | Global Score |
# |------------------|-------------|--------------|
# | Relevance        | 9           | 3            |
# | Completeness     | 8           | 2            |
# | Accuracy         | 7           | 5            |
# | Clarity          | 9           | 6            |
# | Unique Insights  | 8           | 3            |
# | Coherence        | 9           | 5            |
# | Source Diversity | 7           | 2            |
# | Overall          | 8.1         | 3.7          |
#
# TERMINATE
#
# --------------------------------------------------------------------------------
# =============================================
# Evaluating question:
# Create a comprehensive table comparing representation learning models for polymers. Include the following information for each model:
#
# Model name
# Year introduced
# Key authors/research group
# Type of representation (e.g., graph-based, sequence-based, 3D structure-based)
# Input features used
# Dimensionality of the learned representation
# Training data type and size
# Key applications (e.g., property prediction, polymer design)
# Notable advantages
# Limitations or challenges
#
# After the table, provide a brief analysis (2-3 paragraphs) of the current trends in polymer representation learning, highlighting the most promising approaches and areas for future research. Please cite relevant papers for each model and in your analysis.
# , model: gpt-4o
# =============================================
# user_proxy (to gpt4_evaluator):
#
#
#     Evaluate and compare the following search results for the question: "
# Create a comprehensive table comparing representation learning models for polymers. Include the following information for each model:
#
# Model name
# Year introduced
# Key authors/research group
# Type of representation (e.g., graph-based, sequence-based, 3D structure-based)
# Input features used
# Dimensionality of the learned representation
# Training data type and size
# Key applications (e.g., property prediction, polymer design)
# Notable advantages
# Limitations or challenges
#
# After the table, provide a brief analysis (2-3 paragraphs) of the current trends in polymer representation learning, highlighting the most promising approaches and areas for future research. Please cite relevant papers for each model and in your analysis.
# "
#
#     Model used: gpt-4o
#
#     Local search result:
#     Unfortunately, the data tables provided do not contain specific information on the year of introduction, key authors, or research groups associated with the representation learning models for polymers. Additionally, details such as the dimensionality of the learned representation, training data type and size, and the limitations or challenges of each model are not available in the provided data. However, I can compile a table with the information that is available from the data tables and then provide an analysis based on that information.
#
# | Model Name                  | Type of Representation | Input Features Used | Key Applications | Notable Advantages | Limitations or Challenges |
# |-----------------------------|------------------------|---------------------|------------------|--------------------|---------------------------|
# | POLYMER GRAPH REPRESENTATION | Graph-based            | Periodicity, repeat units, monomer composition | Property prediction | Improves prediction accuracy, captures periodicity | Not specified |
# | MMPOLYMER                   | Multimodal (sequence-based and 3D structure-based) | 1D sequential information (P-SMILES strings), 3D structural information | Property prediction | Superior performance across various tasks, adaptable to different datasets | Not specified |
# | TRANS-POLYMER               | Not specified          | Long and short polymer sequences | Not specified | Can learn meaningful representations from both long and short sequences | Not specified |
# | POLYMER SURROGATE MODELS    | Not specified          | Not specified | Polymer design | Used by polymer design algorithms to accelerate discovery | Not specified |
#
# [Data: Entities (14195, 20635, 12980, 9568); Relationships (21703, 17848, 21202, 17899)].
#
# ### Analysis of Current Trends in Polymer Representation Learning
#
# The field of polymer informatics is rapidly evolving, with various representation learning models being developed to predict polymer properties and aid in polymer design. Graph-based representations, such as the Polymer Graph Representation, are particularly promising due to their ability to capture the inherent periodicity and extended chain structures of polymers, which are crucial for accurate property predictions [Data: Entities (14195); Relationships (21703, 21709, 21711)]. These models have shown to significantly reduce prediction errors for properties like the glass transition temperature (Tg) and ionization energy [Data: Relationships (930, 1709)].
#
# Multimodal models like MMPolymer represent another cutting-edge approach. By integrating both sequential and structural information, MMPolymer has demonstrated superior performance across various polymer property datasets [Data: Entities (20635)]. Its adaptability to different datasets and the ability to enhance predictive capabilities through fine-tuning make it a versatile tool in computational polymer science [Data: Relationships (17848)].
#
# Despite these advancements, the field still faces challenges, such as the need for large datasets to train more complex models and the difficulty in capturing the full complexity of polymer systems. Future research may focus on developing more efficient training methods, improving the interpretability of models, and expanding the types of polymer properties that can be predicted. Additionally, as the field grows, there will be a greater need for standardized datasets and benchmarks to compare the performance of different models effectively.
#
#     Global search result:
#     I am sorry but I am unable to answer this question given the provided data.
#
#     Please provide a detailed evaluation considering the following criteria:
#     1. Relevance: How well does each result address the question?
#     2. Completeness: Which result provides more comprehensive information?
#     3. Accuracy: Are there any apparent errors or inconsistencies in either result?
#     4. Clarity: Which result is easier to understand?
#     5. Unique insights: Does either result provide unique information not present in the other?
#     6. Coherence: How well-structured and logically connected is the information in each result?
#     7. Source diversity: Does the result appear to draw from a variety of sources or perspectives?
#
#     For each criterion, provide a brief explanation of your reasoning, followed by a score for both Local and Global results on a scale of 1-10.
#
#     After your analysis, provide an overall score for each result, taking into account all the above criteria.
#
#     Finally, conclude with a brief statement on which result (Local or Global) you think is better for this particular question and why.
#
#     At the end of your analysis, provide a structured table with all the numerical scores using the following format:
#
#     EVALUATION TABLE
#     | Criterion        | Local Score | Global Score |
#     |------------------|-------------|--------------|
#     | Relevance        |             |              |
#     | Completeness     |             |              |
#     | Accuracy         |             |              |
#     | Clarity          |             |              |
#     | Unique Insights  |             |              |
#     | Coherence        |             |              |
#     | Source Diversity |             |              |
#     | Overall          |             |              |
#
#     Fill in the table with your numerical scores, ensuring all scores are between 1 and 10.
#
#     End your evaluation with the word TERMINATE.
#
#
# --------------------------------------------------------------------------------
# gpt4_evaluator (to user_proxy):
#
# Evaluation of Local and Global Search Results:
#
# 1. Relevance:
# Local - The local result attempts to address the question by compiling a table with available information. However, the table lacks comprehensive details as it is missing year, authors, and other requested specifics.
# Score: 4
#
# Global - The global result does not address the question as it indicates inability to answer based on the provided data.
# Score: 1
#
# 2. Completeness:
# Local - The local result is incomplete with respect to the original request but does attempt to provide a structured response with available information.
# Score: 4
#
# Global - Does not offer any information and acknowledges the lack of data for a response.
# Score: 1
#
# 3. Accuracy:
# Local - Without details on the source material, it's difficult to assess accuracy. Assuming the provided data is accurate, this score reflects that there are no clear errors in the presented information.
# Score: 5
#
# Global - Not applicable due to the lack of provided content.
# Score: 1
#
# 4. Clarity:
# Local - The local result clearly presents the information despite its incompleteness. It includes a table and a two-paragraph analysis for clarity.
# Score: 6
#
# Global - There is nothing to evaluate for clarity since it does not provide any data.
# Score: 1
#
# 5. Unique Insights:
# Local - Provides some unique insights in the analysis section, discussing the benefits of graph-based representations and challenges in the field.
# Score: 5
#
# Global - No insights are provided.
# Score: 1
#
# 6. Coherence:
# Local - The information is structured logically with a table followed by a coherent analysis of the trends in polymer representation learning.
# Score: 6
#
# Global - Does not provide any structured or coherent information.
# Score: 1
#
# 7. Source Diversity:
# Local - It is unclear what sources or variety of perspectives the Local result has considered due to lack of citation specifics.
# Score: 3
#
# Global - This criterion is not applicable as the global result did not provide information.
# Score: 1
#
# Calculating the overall score:
# Local - The overall score for the local result is calculated as the average of the scores given for each criterion: (4+4+5+6+5+6+3)/7 = 4.7 (rounded to 5 for the purpose of the table).
#
# Global - The global result overall score reflects the non-response to the query: (1+1+1+1+1+1+1)/7 = 1
#
# EVALUATION TABLE
#
# | Criterion        | Local Score | Global Score |
# |------------------|-------------|--------------|
# | Relevance        | 4           | 1            |
# | Completeness     | 4           | 1            |
# | Accuracy         | 5           | 1            |
# | Clarity          | 6           | 1            |
# | Unique Insights  | 5           | 1            |
# | Coherence        | 6           | 1            |
# | Source Diversity | 3           | 1            |
# | Overall          | 5           | 1            |
#
# The local result is clearly better for this particular question because it attempts to address the question and provides some structured information, including a table and a brief analysis, despite the lack of detail in some areas. On the other hand, the global result provides no information and concedes its inability to answer, making it less useful for someone seeking information on the topic.
#
# TERMINATE
#
# --------------------------------------------------------------------------------
# =============================================
# Evaluating question:
# Create a comparative analysis of machine learning models used for predicting glass transition temperature (Tg) and melting temperature (Tm) of polymers. Include the following in your analysis:
#
# A table comparing at least 5 different models, with the following information for each:
# a) Model name and type (e.g., Random Forest, Neural Network, etc.)
# b) Year introduced
# c) Key authors/research group
# d) Input features or representation used
# e) Dataset size and composition
# f) Accuracy metrics for Tg prediction (e.g., R², RMSE, MAE)
# g) Accuracy metrics for Tm prediction (e.g., R², RMSE, MAE)
# h) Computational complexity or training time (if available)
# A brief discussion (2-3 paragraphs) on:
# a) The overall trends in prediction accuracy for Tg vs Tm
# b) Factors that contribute to higher accuracy in certain models
# c) Challenges in predicting these properties accurately
# d) Recent advancements or novel approaches in the field
# A short section on potential areas for improvement and future research directions.
#
# Please provide citations for the models and studies mentioned in your analysis.
# , model: gpt-4o
# =============================================
# user_proxy (to gpt4_evaluator):
#
#
#     Evaluate and compare the following search results for the question: "
# Create a comparative analysis of machine learning models used for predicting glass transition temperature (Tg) and melting temperature (Tm) of polymers. Include the following in your analysis:
#
# A table comparing at least 5 different models, with the following information for each:
# a) Model name and type (e.g., Random Forest, Neural Network, etc.)
# b) Year introduced
# c) Key authors/research group
# d) Input features or representation used
# e) Dataset size and composition
# f) Accuracy metrics for Tg prediction (e.g., R², RMSE, MAE)
# g) Accuracy metrics for Tm prediction (e.g., R², RMSE, MAE)
# h) Computational complexity or training time (if available)
# A brief discussion (2-3 paragraphs) on:
# a) The overall trends in prediction accuracy for Tg vs Tm
# b) Factors that contribute to higher accuracy in certain models
# c) Challenges in predicting these properties accurately
# d) Recent advancements or novel approaches in the field
# A short section on potential areas for improvement and future research directions.
#
# Please provide citations for the models and studies mentioned in your analysis.
# "
#
#     Model used: gpt-4o
#
#     Local search result:
#     # Comparative Analysis of Machine Learning Models for Polymer Property Prediction
#
# ## Table of Comparative Analysis
#
# | Model Name and Type | Year | Key Authors/Group | Input Features | Dataset Size | Tg Prediction Accuracy | Tm Prediction Accuracy | Computational Complexity |
# |---------------------|------|-------------------|----------------|--------------|------------------------|------------------------|--------------------------|
# | MPNN (Message Passing Neural Network) | 2021 | L. Tao, V. Varshney, Y. Li | Polymer graph representation | Not specified | RMSE: 27°C (subset) | Not available | Not specified |
# | RF (Random Forest) | Not specified | Not specified | Tg dataset | Not specified | Not specified | Not specified | Not specified |
# | polyBERT | Not specified | Not specified | Not specified | Not specified | Not specified | Not specified | Not specified |
# | Polymer Genome | Not specified | Not specified | Not specified | Not specified | Not specified | Not specified | Not specified |
# | Machine-Learning-Based Predictive Modeling | 2019 | G. Pilania, C. N. Iverson, T. Lookman, B. L. Marrone | Polyhydroxyalkanoate homopolymers and copolymers | Not specified | Not specified | Not specified | Not specified |
#
# *Note: The table includes models for which specific information about Tg prediction accuracy is available. Other models and their details are not fully specified in the provided data.*
#
# ## Discussion
#
# ### Trends in Prediction Accuracy for Tg vs Tm
# The prediction accuracy for glass transition temperature (Tg) and melting temperature (Tm) can vary significantly across different machine learning models. While the table above provides specific accuracy metrics for Tg prediction using the MPNN model, it is not possible to directly compare these results with Tm predictions due to a lack of available data. However, it is generally observed that Tg predictions can be challenging due to the complex nature of amorphous polymers and the subtle changes in their structure that can significantly affect Tg [Data: Relationships (3554, 21709, 3555, 21762)].
#
# ### Factors Contributing to Higher Accuracy
# Certain models, such as MPNN, show promise in accurately predicting Tg due to their ability to capture the nuanced structural features of polymers through polymer graph representations [Data: Relationships (3554, 21709)]. The use of comprehensive datasets and advanced neural network architectures can also contribute to higher prediction accuracy. The inclusion of domain-specific features, such as the presence of polar functional groups or rigid ring structures, can further enhance the model's predictive capabilities [Data: Relationships (21776, 21777)].
#
# ### Challenges in Accurate Prediction
# Accurately predicting Tg and Tm is complicated by the inherent variability in polymer structures and the sensitivity of these properties to subtle molecular differences. The lack of large, high-quality datasets and the computational complexity of simulating polymer behaviors also pose significant challenges [Data: Relationships (339, 17294, 16053)].
#
# ### Recent Advancements
# Recent advancements in the field include the development of novel neural network architectures, such as MPNN, which can better capture the complexity of polymer structures [Data: Relationships (3554, 21709)]. Additionally, the use of chemical language processing models and the integration of cheminformatics with molecular dynamics simulations are emerging as promising approaches [Data: Relationships (1272, 9724)].
#
# ## Future Research Directions
# Future research could focus on expanding and curating high-quality datasets for both Tg and Tm predictions. The development of models that can account for the dynamic nature of polymers and incorporate real-world processing conditions will also be crucial. Furthermore, exploring transfer learning and multi-fidelity modeling approaches may help in leveraging available data more effectively. Advancements in computational power and algorithms that reduce the computational complexity of simulations will enable more extensive and accurate predictions.
#
# *Citations:*
# - L. Tao, V. Varshney, Y. Li, "Benchmarking Machine Learning Models for Polymer Informatics: An Example of Glass Transition Temperature," J. Chem. Inf. Model., 2021, 61, 5395-5413 [Data: Sources (561)].
# - G. Pilania, C. N. Iverson, T. Lookman, B. L. Marrone, "Machine-Learning-Based Predictive Modeling of Glass Transition Temperatures: A Case of Polyhydroxyalkanoate Homopolymers and Copolymers," J. Chem. Inf. Model., 2019, 59, 5013-5025 [Data: Sources (557)].
# - Additional references from the provided data tables [Data: Entities, Relationships, Sources].
#
#     Global search result:
#     I am sorry but I am unable to answer this question given the provided data.
#
#     Please provide a detailed evaluation considering the following criteria:
#     1. Relevance: How well does each result address the question?
#     2. Completeness: Which result provides more comprehensive information?
#     3. Accuracy: Are there any apparent errors or inconsistencies in either result?
#     4. Clarity: Which result is easier to understand?
#     5. Unique insights: Does either result provide unique information not present in the other?
#     6. Coherence: How well-structured and logically connected is the information in each result?
#     7. Source diversity: Does the result appear to draw from a variety of sources or perspectives?
#
#     For each criterion, provide a brief explanation of your reasoning, followed by a score for both Local and Global results on a scale of 1-10.
#
#     After your analysis, provide an overall score for each result, taking into account all the above criteria.
#
#     Finally, conclude with a brief statement on which result (Local or Global) you think is better for this particular question and why.
#
#     At the end of your analysis, provide a structured table with all the numerical scores using the following format:
#
#     EVALUATION TABLE
#     | Criterion        | Local Score | Global Score |
#     |------------------|-------------|--------------|
#     | Relevance        |             |              |
#     | Completeness     |             |              |
#     | Accuracy         |             |              |
#     | Clarity          |             |              |
#     | Unique Insights  |             |              |
#     | Coherence        |             |              |
#     | Source Diversity |             |              |
#     | Overall          |             |              |
#
#     Fill in the table with your numerical scores, ensuring all scores are between 1 and 10.
#
#     End your evaluation with the word TERMINATE.
#
#
# --------------------------------------------------------------------------------
# gpt4_evaluator (to user_proxy):
#
# To evaluate the search results based on the provided criteria, let's go through them one by one.
#
# ### Relevance
# - **Local Search Result:** This result provides a table comparing different models with some fields filled out, even though it's not complete for all models. It also includes a discussion related to Tg and Tm predictions.
# - **Global Search Result:** This result states that it cannot provide an answer, showing no relevance to the question.
#
# **Scores:**
# Local Score: 6 (partially relevant with some details)
# Global Score: 1 (irrelevant as it provides no data)
#
# ### Completeness
# - **Local Search Result:** Attempts to deliver a table and a discussion but lacks complete details for all models.
# - **Global Search Result:** Offers no information.
#
# **Scores:**
# Local Score: 5 (incomplete but attempts to address the requirements)
# Global Score: 1 (provides no information)
#
# ### Accuracy
# - **Local Search Result:** No apparent factual errors were stated since citation is provided, but the specificity and detail expected in the table are lacking—that said, there is no way to verify the accuracy without the sources.
# - **Global Search Result:** Cannot be inaccurate as it provides no information.
#
# **Scores:**
# Local Score: 5 (assuming the cited data is accurate)
# Global Score: NA (not applicable as there’s nothing to compare)
#
# ### Clarity
# - **Local Search Result:** The structure is clear and attempts to organize information into a table and discussion sections.
# - **Global Search Result:** Not applicable as it provides no answer.
#
# **Scores:**
# Local Score: 7 (clear structuring of contents but incomplete)
# Global Score: NA (not applicable)
#
# ### Unique Insights
# - **Local Search Result:** Offers specific details such as the RMSE for Tg prediction by the MPNN model and touches on recent advancements.
# - **Global Search Result:** Provides no insights.
#
# **Scores:**
# Local Score: 6 (some insights given)
# Global Score: 1 (no insights provided)
#
# ### Coherence
# - **Local Search Result:** Information is presented in an organized format, with a clear sequence from the table to the discussion.
# - **Global Search Result:** There is no information to judge coherence.
#
# **Scores:**
# Local Score: 7 (coherent structure)
# Global Score: NA (not applicable)
#
# ### Source Diversity
# - **Local Search Result:** Cites specific studies, indicating that some source diversity was attempted.
# - **Global Search Result:** There’s no mention of any sources.
#
# **Scores:**
# Local Score: 5 (some sources are mentioned, but not diverse)
# Global Score: 1 (no sources provided)
#
# ### Overall
# The overall score is a subjective judgment taking into account all of the criteria.
#
# **Scores:**
# Local Score: 6 (provides some relevant information but incomplete)
# Global Score: 1 (does not contribute any information)
#
# Based on the criteria, the Local search result is better suited for the question as it attempts to provide the relevant information and discusses the subject matter, despite its incompleteness and the lack of detailed data for all models.
#
# Here is the evaluation table filled out with the scores:
#
# ```
# EVALUATION TABLE
# | Criterion        | Local Score | Global Score |
# |------------------|-------------|--------------|
# | Relevance        | 6           | 1            |
# ...
#
# EVALUATION TABLE
# | Criterion        | Local Score | Global Score |
# |------------------|-------------|--------------|
# | Relevance        | 6           | 1            |
# | Completeness     | 5           | 1            |
# | Accuracy         | 7           | 10           |
# | Clarity          | 8           | 10           |
# | Unique Insights  | 6           | 1            |
# | Coherence        | 7           | 1            |
# | Source Diversity | 3           | 1            |
# | **Overall**      | **6**       | **4**        |
#
# In conclusion, the Local result is better for this particular question since it provides a partial answer with some related content and overview, whereas the Global result declines to engage with the question's content.
#
# TERMINATE
#
# --------------------------------------------------------------------------------
# Warning: Invalid score format: **6** for criterion **overall**
# =============================================
# Evaluating question:
# Create a comparative analysis of machine learning models used for predicting glass transition temperature (Tg) and melting temperature (Tm) of polymers. Include the following in your analysis:
#
# A table comparing at least 5 different models, with the following information for each:
# a) Model name and type (e.g., Random Forest, Neural Network, etc.)
# b) Year introduced
# c) Key authors/research group
# d) Input features or representation used
# e) Dataset size and composition
# f) Accuracy metrics for Tg prediction (e.g., R², RMSE, MAE)
# g) Accuracy metrics for Tm prediction (e.g., R², RMSE, MAE)
# h) Computational complexity or training time (if available)
# A brief discussion (2-3 paragraphs) on:
# a) The overall trends in prediction accuracy for Tg vs Tm
# b) Factors that contribute to higher accuracy in certain models
# c) Challenges in predicting these properties accurately
# d) Recent advancements or novel approaches in the field
# A short section on potential areas for improvement and future research directions.
#
# Please provide citations for the models and studies mentioned in your analysis.
# , model: gpt-35-turbo-16k
# =============================================
# user_proxy (to gpt4_evaluator):
#
#
#     Evaluate and compare the following search results for the question: "
# Create a comparative analysis of machine learning models used for predicting glass transition temperature (Tg) and melting temperature (Tm) of polymers. Include the following in your analysis:
#
# A table comparing at least 5 different models, with the following information for each:
# a) Model name and type (e.g., Random Forest, Neural Network, etc.)
# b) Year introduced
# c) Key authors/research group
# d) Input features or representation used
# e) Dataset size and composition
# f) Accuracy metrics for Tg prediction (e.g., R², RMSE, MAE)
# g) Accuracy metrics for Tm prediction (e.g., R², RMSE, MAE)
# h) Computational complexity or training time (if available)
# A brief discussion (2-3 paragraphs) on:
# a) The overall trends in prediction accuracy for Tg vs Tm
# b) Factors that contribute to higher accuracy in certain models
# c) Challenges in predicting these properties accurately
# d) Recent advancements or novel approaches in the field
# A short section on potential areas for improvement and future research directions.
#
# Please provide citations for the models and studies mentioned in your analysis.
# "
#
#     Model used: gpt-35-turbo-16k
#
#     Local search result:
#     # Comparative Analysis of Machine Learning Models for Polymer Property Prediction
#
# ## Table of Comparative Analysis
#
# | Model Name and Type | Year | Key Authors/Group | Input Features | Dataset Size | Tg Prediction Accuracy | Tm Prediction Accuracy | Computational Complexity |
# |---------------------|------|-------------------|----------------|--------------|------------------------|------------------------|--------------------------|
# | MPNN (Message Passing Neural Network) | 2021 | L. Tao, V. Varshney, Y. Li | Polymer graph representation | Not specified | RMSE: 27°C (subset) | Not available | Not specified |
# | RF (Random Forest) | Not specified | Not specified | Tg dataset | Not specified | Not specified | Not specified | Not specified |
# | polyBERT | Not specified | Not specified | Not specified | Not specified | Not specified | Not specified | Not specified |
# | Polymer Genome | Not specified | Not specified | Not specified | Not specified | Not specified | Not specified | Not specified |
# | MMPolymer | Not specified | Not specified | Not specified | Not specified | Not specified | Not specified | Not specified |
#
# *Note: The table includes models mentioned in the dataset, but specific details such as year introduced, key authors, input features, dataset size and composition, and computational complexity are not provided in the dataset. The accuracy metrics for Tg prediction are only partially available for the MPNN model [Data: Relationships (3554, 21709, 3555, 21762, 532, +more)].
#
# ## Discussion
#
# ### Trends in Prediction Accuracy
# The prediction accuracy for glass transition temperature (Tg) and melting temperature (Tm) of polymers varies across different machine learning models. The MPNN model, which uses a polymer graph representation, has shown promising results with an RMSE of 27°C for a subset of polymers [Data: Relationships (3554, 21709)]. However, the dataset does not provide a direct comparison for Tm prediction accuracy or a comprehensive comparison across models for Tg prediction accuracy.
#
# ### Factors Contributing to Higher Accuracy
# Certain models achieve higher accuracy in predicting polymer properties due to the sophistication of their input features and the ability to capture complex relationships within the data. For instance, the polymer graph representation used by the MPNN model allows for a more nuanced understanding of polymer structures, which can lead to more accurate predictions [Data: Relationships (3554, 21709)].
#
# ### Challenges in Prediction
# Challenges in accurately predicting Tg and Tm include the inherent complexity of polymer structures, the variability in experimental data, and the limitations of the datasets used for training the models. The dataset uncertainties can significantly impact the model predictions [Data: Relationships (416, 9724)].
#
# ### Recent Advancements
# Recent advancements in the field include the development of novel neural network architectures, such as MPNN, and the use of chemical language processing models for predicting polymer properties [Data: Relationships (1294, 1295, 1296, 1297, 1298, +more)]. These approaches leverage advanced computational techniques to better understand and predict the behavior of complex polymer systems.
#
# ## Future Research Directions
# Potential areas for improvement and future research directions include expanding and standardizing datasets, developing more sophisticated models that can account for a wider range of polymer features, and improving the interpretability of machine learning models. Additionally, integrating multi-fidelity modeling approaches that combine different levels of computational and experimental data could enhance prediction accuracy and reliability.
#
# *Note: The analysis is based on the information provided in the dataset. Specific citations for the models and studies mentioned are not available within the dataset. The discussion incorporates general knowledge on the topic.
#
#     Global search result:
#     ### Comparative Analysis of Machine Learning Models for Polymer Property Prediction
#
# #### Table of Comparative Analysis
#
# Unfortunately, the dataset provided does not contain sufficient information to construct a comprehensive table comparing different machine learning models for predicting the glass transition temperature (Tg) and melting temperature (Tm) of polymers. The details required for such a comparison, including the year introduced, key authors, input features, dataset size and composition, accuracy metrics, and computational complexity, are not available in the provided reports.
#
# #### Discussion on Prediction Accuracy Trends and Factors
#
# The dataset includes a reference to a study on 'Machine-learning-assisted low dielectric constant polymer discovery' by Zhao, Y. and others, which may involve machine learning for polymer property prediction. However, it does not provide specific details on Tg or Tm prediction [Data: Reports (462)]. Additionally, there is a mention of an RF Model used for predicting polymer properties, which could potentially include Tg, but there is no mention of Tm prediction or comparative analysis with other models [Data: Reports (920)]. Without these details, it is not possible to discuss overall trends in prediction accuracy for Tg versus Tm, factors contributing to higher accuracy in certain models, challenges in predicting these properties accurately, or recent advancements in the field.
#
# #### Potential Areas for Improvement and Future Research Directions
#
# Given the lack of detailed information, we cannot identify specific areas for improvement or suggest future research directions based on the dataset. To advance the field of polymer property prediction using machine learning, comprehensive datasets that include a variety of models, their performance metrics, and computational details are essential. Researchers may focus on gathering such data to enable a thorough comparative analysis in the future.
#
# #### Citations
#
# The response cannot provide citations for the models and studies mentioned in the analysis due to the absence of detailed information in the provided dataset.
#
# ---
#
# In summary, the dataset does not contain the necessary information to perform a comparative analysis of machine learning models for predicting Tg and Tm of polymers. To conduct such an analysis, a more detailed dataset that includes specific information about the models, their performance, and computational aspects is required.
#
#     Please provide a detailed evaluation considering the following criteria:
#     1. Relevance: How well does each result address the question?
#     2. Completeness: Which result provides more comprehensive information?
#     3. Accuracy: Are there any apparent errors or inconsistencies in either result?
#     4. Clarity: Which result is easier to understand?
#     5. Unique insights: Does either result provide unique information not present in the other?
#     6. Coherence: How well-structured and logically connected is the information in each result?
#     7. Source diversity: Does the result appear to draw from a variety of sources or perspectives?
#
#     For each criterion, provide a brief explanation of your reasoning, followed by a score for both Local and Global results on a scale of 1-10.
#
#     After your analysis, provide an overall score for each result, taking into account all the above criteria.
#
#     Finally, conclude with a brief statement on which result (Local or Global) you think is better for this particular question and why.
#
#     At the end of your analysis, provide a structured table with all the numerical scores using the following format:
#
#     EVALUATION TABLE
#     | Criterion        | Local Score | Global Score |
#     |------------------|-------------|--------------|
#     | Relevance        |             |              |
#     | Completeness     |             |              |
#     | Accuracy         |             |              |
#     | Clarity          |             |              |
#     | Unique Insights  |             |              |
#     | Coherence        |             |              |
#     | Source Diversity |             |              |
#     | Overall          |             |              |
#
#     Fill in the table with your numerical scores, ensuring all scores are between 1 and 10.
#
#     End your evaluation with the word TERMINATE.
#
#
# --------------------------------------------------------------------------------
# gpt4_evaluator (to user_proxy):
#
# EVALUATION CRITERIA:
#
# 1. Relevance:
# The Local result attempts to directly address the question by generating a table and providing a summary of machine learning methods and their performance on predicting Tg, with a brief mention of Tm prediction (although 'Not available'). It lacks detailed information but tries to maintain relevance to the query. The Global result acknowledges the insufficiency of the dataset for a comprehensive analysis and stays relevant by discussing the limitations and the inability to address the question in depth due to incomplete information.
#
# Local Score: 6
# Global Score: 5
#
# 2. Completeness:
# The Local result, despite missing details, presents a table with some attempt to outline various models and a discussion. However, the lack of specific information reduces the completeness. The Global result also does not provide a complete answer by stating that the necessary data is not available and thus cannot present the required analysis.
#
# Local Score: 5
# Global Score: 3
#
# 3. Accuracy:
# Neither result provides erroneous information, but they both suffer from a lack of detailed and specific data. The Local result cites some accuracy metrics for the MPNN model without complete references or data validation. The Global result is cautious and refrains from potentially inaccurate details due to insufficient data.
#
# Local Score: 4
# Global Score: 5
#
# 4. Clarity:
# The Local result provides a clearer response by trying to format the available data into the requested analysis structure, albeit with incomplete information. The Global result is clear in stating the lack of information but does not provide additional clarity regarding the specific question asked.
#
# Local Score: 7
# Global Score: 6
#
# 5. Unique Insights:
# The Local result provides some insights into the trends and potential of certain machine learning models, even if specifics are lacking. It mentions recent advancements and potential future research directions. The Global result does not offer unique insights but only comments on the insufficiency of the provided dataset.
#
# Local Score: 6
# Global Score: 3
#
# 6. Coherence:
# Both results are logically structured but the Local result attempts to follow the structure of the presented question more closely. It connects the discussion points and future directions despite missing data. The Global result is coherent but brief and lacks a concrete analysis.
#
# Local Score: 7
# Global Score: 5
#
# 7. Source Diversity:
# Neither result demonstrates source diversity as both acknowledge the lack of comprehensive data. It's unclear from either result if there was any consideration of multiple sources or perspectives due to the dataset’s limitations.
#
# Local Score: 3
# Global Score: 3
#
# Considering all the above criteria, the following are the overall scores:
#
# Local Score: 5.4
# Global Score: 4.3
#
# To conclude, the Local result is marginally better for this particular question because, despite the lack of detailed information, it attempts to construct a response that is more aligned with the format and substance of the original question. It tries to synthesize an analysis with the scarce data provided, giving at least a partial view of the subject matter requested in the query. The Global result, while also grappling with the same dataset limitations, does not provide much beyond the acknowledgment of these limitations.
#
# EVALUATION TABLE
# | Criterion        | Local Score | Global Score |
# |------------------|-------------|--------------|
# | Relevance        |      6      |       5      |
# | Completeness     |      5      |       3      |
# | Accuracy         |      4      |       5      |
# | Clarity          |      7      |       6      |
# | Unique Insights  |      6      |       3      |
# | Coherence        |      7      |       5      |
# | Source Diversity |      3      |       3      |
# | Overall          |     5.4     |      4.3     |
#
# TERMINATE
#
# --------------------------------------------------------------------------------
# Evaluations completed and saved to evaluations_20240904_044022.csv
# Evaluations also saved as JSON to evaluations_20240904_044022.json

# %%
def compare_local_global_per_model(evaluations_df: pd.DataFrame) -> pd.DataFrame:
    # Melt the DataFrame to get all scores in one column
    melted = pd.melt(evaluations_df, 
                     id_vars=['model'], 
                     value_vars=[col for col in evaluations_df.columns if col.startswith('score_')],
                     var_name='criterion', 
                     value_name='score')
    
    # Split the criterion into base criterion and search type
    melted[['criterion', 'search_type']] = melted['criterion'].str.split('_', n=2, expand=True)[1].str.split('.', n=2, expand=True)
    
    # Pivot the DataFrame to get local and global scores side by side
    pivoted = melted.pivot_table(values='score', 
                                 index=['model', 'search_type'], 
                                 columns='criterion', 
                                 aggfunc='mean')
    
    # Swap levels to get search_type as the first level
    pivoted = pivoted.swaplevel(0, 1, axis=0)
    
    # Sort index to group local and global together
    pivoted = pivoted.sort_index()
    
    return pivoted

# %%
def compare_across_models(evaluations_df: pd.DataFrame, search_type: str) -> pd.DataFrame:
    # Filter columns for the specified search type
    score_columns = [col for col in evaluations_df.columns if col.startswith(f'score_') and col.endswith(f'.{search_type}')]
    
    # Select relevant columns and group by model
    grouped = evaluations_df[['model'] + score_columns].groupby('model')
    
    # Calculate mean scores for each model
    mean_scores = grouped.mean()
    
    # Reset index to make 'model' a regular column
    mean_scores = mean_scores.reset_index()
    
    # Rename columns for clarity
    mean_scores.columns = [col.replace(f'score_', '').replace(f'.{search_type}', '') for col in mean_scores.columns]
    
    return mean_scores

# %%
df_questions = evaluations_df[evaluations_df['question'] == questions[0]]

# Compare Local and Global search for each model
local_global_comparison = compare_local_global_per_model(df_questions)
print(f"question: {questions[0]}")
print("\nLocal vs Global comparison for each model:")
local_global_comparison
# Out:
# question:
# Create a comprehensive table comparing representation learning models for polymers. Include the following information for each model:
#
# Model name
# Year introduced
# Key authors/research group
# Type of representation (e.g., graph-based, sequence-based, 3D structure-based)
# Input features used
# Dimensionality of the learned representation
# Training data type and size
# Key applications (e.g., property prediction, polymer design)
# Notable advantages
# Limitations or challenges
#
# After the table, provide a brief analysis (2-3 paragraphs) of the current trends in polymer representation learning, highlighting the most promising approaches and areas for future research. Please cite relevant papers for each model and in your analysis.
#
#
# Local vs Global comparison for each model:
# criterion                     accuracy  clarity  coherence  completeness  \
# search_type model
# global      gpt-35-turbo           NaN      2.0        1.0           1.0
#             gpt-35-turbo-16k      10.0     10.0        1.0           1.0
#             gpt-4                 10.0      4.0        2.0           2.0
#             gpt-4-mini             NaN      1.0        1.0           1.0
#             gpt-4o                 1.0      1.0        1.0           1.0
# local       gpt-35-turbo           7.0      8.0        8.0           5.0
#             gpt-35-turbo-16k       7.0      8.0        7.0           5.0
#             gpt-4                 10.0      7.0        6.0           4.0
#             gpt-4-mini             NaN      8.0        7.0           5.0
#             gpt-4o                 5.0      6.0        6.0           4.0
#
# criterion                     overall  relevance
# search_type model
# global      gpt-35-turbo          NaN        1.0
#             gpt-35-turbo-16k      NaN        1.0
#             gpt-4                 3.0        3.0
#             gpt-4-mini            1.0        1.0
#             gpt-4o                1.0        1.0
# local       gpt-35-turbo          NaN        7.0
#             gpt-35-turbo-16k      NaN        6.0
#             gpt-4                 5.0        5.0
#             gpt-4-mini            6.0        7.0
#             gpt-4o                5.0        4.0

# %%
df_questions = evaluations_df[evaluations_df['question'] == questions[1]]

# Compare Local and Global search for each model
local_global_comparison = compare_local_global_per_model(df_questions)
print(f"question: {questions[0]}")
print("\nLocal vs Global comparison for each model:")
local_global_comparison
# Out:
# question:
# Create a comprehensive table comparing representation learning models for polymers. Include the following information for each model:
#
# Model name
# Year introduced
# Key authors/research group
# Type of representation (e.g., graph-based, sequence-based, 3D structure-based)
# Input features used
# Dimensionality of the learned representation
# Training data type and size
# Key applications (e.g., property prediction, polymer design)
# Notable advantages
# Limitations or challenges
#
# After the table, provide a brief analysis (2-3 paragraphs) of the current trends in polymer representation learning, highlighting the most promising approaches and areas for future research. Please cite relevant papers for each model and in your analysis.
#
#
# Local vs Global comparison for each model:
# criterion                     accuracy  clarity  coherence  completeness  \
# search_type model
# global      gpt-35-turbo           6.0      5.0        3.0           2.0
#             gpt-35-turbo-16k       5.0      6.0        5.0           3.0
#             gpt-4                  5.0      6.0        5.0           2.0
#             gpt-4-mini             NaN      1.0        1.0           1.0
#             gpt-4o                 NaN      NaN        NaN           1.0
# local       gpt-35-turbo           8.0      8.0        8.0           7.0
#             gpt-35-turbo-16k       4.0      7.0        7.0           5.0
#             gpt-4                  7.0      9.0        9.0           8.0
#             gpt-4-mini             6.0      6.0        6.0           5.0
#             gpt-4o                 5.0      7.0        7.0           5.0
#
# criterion                     overall  relevance
# search_type model
# global      gpt-35-turbo          3.1        3.0
#             gpt-35-turbo-16k      4.3        5.0
#             gpt-4                 3.7        3.0
#             gpt-4-mini            1.0        1.0
#             gpt-4o                1.0        1.0
# local       gpt-35-turbo          7.4        8.0
#             gpt-35-turbo-16k      5.4        6.0
#             gpt-4                 8.1        9.0
#             gpt-4-mini            5.6        7.0
#             gpt-4o                6.0        6.0

# %%
# use iwidget to display the comparison
# local_global_comparison.loc[local_global_comparison.index.get_level_values('model') == 'gpt-4']

from IPython.display import display
import ipywidgets as widgets
from ipywidgets import interact, interact_manual

@interact
def show_comparison(model=models):
    display(local_global_comparison.loc[local_global_comparison.index.get_level_values('model') == model])
# Out:
# interactive(children=(Dropdown(description='model', options=('gpt-4', 'gpt-4o', 'gpt-4o-mini', 'gpt-35-turbo',…

# %%
df_questions = evaluations_df[evaluations_df['question'] == questions[0]]

# Compare local scores across all models
local_comparison = compare_across_models(df_questions, 'local')
local_comparison
# Out:
#               model  relevance  completeness  accuracy  clarity  \
# 0      gpt-35-turbo        7.0           5.0       7.0      8.0
# 1  gpt-35-turbo-16k        6.0           5.0       7.0      8.0
# 2             gpt-4        5.0           4.0      10.0      7.0
# 3        gpt-4-mini        7.0           5.0       NaN      8.0
# 4            gpt-4o        4.0           4.0       5.0      6.0
#
#    unique_insights  coherence  source_diversity  overall
# 0              6.0        8.0               4.0      NaN
# 1              6.0        7.0               3.0      NaN
# 2              3.0        6.0               1.0      5.0
# 3              5.0        7.0               NaN      6.0
# 4              5.0        6.0               3.0      5.0

# %%
df_questions = evaluations_df[evaluations_df['question'] == questions[1]]

# Compare local scores across all models
local_comparison = compare_across_models(df_questions, 'local')
local_comparison
# Out:
#               model  relevance  completeness  accuracy  clarity  \
# 0      gpt-35-turbo        8.0           7.0       8.0      8.0
# 1  gpt-35-turbo-16k        6.0           5.0       4.0      7.0
# 2             gpt-4        9.0           8.0       7.0      9.0
# 3        gpt-4-mini        7.0           5.0       6.0      6.0
# 4            gpt-4o        6.0           5.0       5.0      7.0
#
#    unique_insights  coherence  source_diversity  overall
# 0              7.0        8.0               6.0      7.4
# 1              6.0        7.0               3.0      5.4
# 2              8.0        9.0               7.0      8.1
# 3              5.0        6.0               4.0      5.6
# 4              6.0        7.0               5.0      6.0

# %%
df_questions = evaluations_df[evaluations_df['question'] == questions[0]]

# Compare global scores across all models
local_comparison = compare_across_models(df_questions, 'global')
local_comparison
# Out:
#               model  relevance  completeness  accuracy  clarity  \
# 0      gpt-35-turbo        1.0           1.0       NaN      2.0
# 1  gpt-35-turbo-16k        1.0           1.0      10.0     10.0
# 2             gpt-4        3.0           2.0      10.0      4.0
# 3        gpt-4-mini        1.0           1.0       NaN      1.0
# 4            gpt-4o        1.0           1.0       1.0      1.0
#
#    unique_insights  coherence  source_diversity  overall
# 0              1.0        1.0               1.0      NaN
# 1              1.0        1.0               1.0      NaN
# 2              1.0        2.0               1.0      3.0
# 3              1.0        1.0               NaN      1.0
# 4              1.0        1.0               1.0      1.0

# %%
df_questions = evaluations_df[evaluations_df['question'] == questions[1]]

# Compare global scores across all models
local_comparison = compare_across_models(df_questions, 'global')
local_comparison
# Out:
#               model  relevance  completeness  accuracy  clarity  \
# 0      gpt-35-turbo        3.0           2.0       6.0      5.0
# 1  gpt-35-turbo-16k        5.0           3.0       5.0      6.0
# 2             gpt-4        3.0           2.0       5.0      6.0
# 3        gpt-4-mini        1.0           1.0       NaN      1.0
# 4            gpt-4o        1.0           1.0       NaN      NaN
#
#    unique_insights  coherence  source_diversity  overall
# 0              1.0        3.0               2.0      3.1
# 1              3.0        5.0               3.0      4.3
# 2              3.0        5.0               2.0      3.7
# 3              1.0        1.0               1.0      1.0
# 4              1.0        NaN               1.0      1.0

# %%
# Compare Local and Global search for each model
local_global_comparison = compare_local_global_per_model(evaluations)
print("\nLocal vs Global comparison for each model:")
print(json.dumps(local_global_comparison, indent=2))

# Compare Local search across all models
local_comparison = compare_across_models(evaluations, "local")
print("\nLocal search comparison across all models:")
print(json.dumps(local_comparison, indent=2))

# Compare Global search across all models
global_comparison = compare_across_models(evaluations, "global")
print("\nGlobal search comparison across all models:")
print(json.dumps(global_comparison, indent=2))

# Calculate overall average scores
def calculate_average_scores(evaluations):
    total_scores = {
        "local": defaultdict(float),
        "global": defaultdict(float)
    }
    count = len(evaluations)

    for eval in evaluations:
        for criterion, scores in eval["scores"].items():
            total_scores["local"][criterion] += scores["local"]
            total_scores["global"][criterion] += scores["global"]

    avg_scores = {
        "local": {criterion: score / count for criterion, score in total_scores["local"].items()},
        "global": {criterion: score / count for criterion, score in total_scores["global"].items()}
    }

    return avg_scores

# Calculate and print overall average scores
average_scores = calculate_average_scores(evaluations)
print("\nOverall Average Scores:")
print(json.dumps(average_scores, indent=2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 # Compare Local and Global search for each model
# ----> 2 local_global_comparison = compare_local_global_per_model(evaluations)
#       3 print("\nLocal vs Global comparison for each model:")
#       4 print(json.dumps(local_global_comparison, indent=2))
#
# NameError: name 'evaluations' is not defined

# %%
import math
import re

def parse_evaluation_table(evaluation: str) -> Dict[str, Dict[str, float]]:
    try:
        table_text = evaluation.split("EVALUATION TABLE")[1].split("TERMINATE")[0].strip()
        lines = table_text.split("\n")
        scores = {}
        for line in lines:
            parts = [part.strip() for part in line.split("|") if part.strip()]
            if len(parts) >= 3 and not is_header_or_separator_row(parts):
                criterion = parts[0].lower().replace(" ", "_")
                try:
                    local_score = parse_score(parts[-2])  # Second to last part
                    global_score = parse_score(parts[-1])  # Last part
                    scores[criterion] = {"local": local_score, "global": global_score}
                except ValueError as e:
                    print(f"Warning: {str(e)} for criterion {criterion}")
        
        if not scores:
            raise ValueError("No valid scores found in the evaluation table")
        
        return scores
    except Exception as e:
        print(f"Error parsing evaluation table: {str(e)}")
        return {}

def is_header_or_separator_row(parts: List[str]) -> bool:
    # Check if it's a header row
    if any(header.lower() in " ".join(parts).lower() for header in ["criterion", "local score", "global score"]):
        return True
    
    # Check if it's a separator row (contains only dashes, possibly with colons for alignment)
    if all(re.match(r'^[-:]+$', part) for part in parts):
        return True
    
    return False

def parse_score(score_str: str) -> float:
    score_str = score_str.strip().lower()
    if score_str in ['n/a', ''] or not re.search(r'\d', score_str):
        return math.nan  # Use NaN to represent N/A, empty scores, or non-numeric entries
    try:
        score = float(score_str)
        if 1 <= score <= 10:
            return score
        else:
            raise ValueError(f"Score out of range: {score}")
    except ValueError:
        raise ValueError(f"Invalid score format: {score_str}")
